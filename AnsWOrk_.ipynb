# %% [markdown]
# #Class-Balanced Resampling with SMOTE

# %% [markdown]
# The process is used to balance class distribution in the dataset (`data`) by oversampling minority classes and undersampling majority classes, ensuring each class contributes proportionally to the final dataset (`resampled_data`) of `total_samples` size, crucial for improving machine learning model performance, especially when classes are imbalanced.

# %%
# Load necessary libraries
import pandas as pd
from sklearn.utils import resample

# Load the dataset from the specified file path
file_path = '/content/ANsWork - Sheet1.csv'
data = pd.read_csv(file_path)

# Assuming the first column is the target variable, extract y (target) and X (features)
y = data.iloc[:, 0]    # Target variable
X = data.iloc[:, 1:]   # Features

# Convert the target variable to categorical if it's numeric (int or float)
if y.dtype == 'float64' or y.dtype == 'int64':
    y = y.astype(int).astype(str)

# Combine the target variable and features into a single DataFrame for resampling
data_combined = pd.concat([y, X], axis=1)

# Define the total number of samples desired after resampling
total_samples = 1200

# Calculate the number of samples needed for each class to achieve the desired balance
class_counts = y.value_counts()  # Count occurrences of each class in y
sampling_strategy = {cls: int((count / len(y)) * total_samples) for cls, count in class_counts.items()}

# Resample each class according to the calculated sampling strategy
resampled_data = []
for cls, n_samples in sampling_strategy.items():
    class_data = data_combined[data_combined.iloc[:, 0] == cls]  # Select data for the current class
    resampled_class_data = resample(class_data, replace=True, n_samples=n_samples, random_state=42)  # Resample with replacement
    resampled_data.append(resampled_class_data)

# Combine all resampled data into a single DataFrame
resampled_data = pd.concat(resampled_data)

# Save the resampled data to a new CSV file
output_file_path = '/content/resampled_dataset.csv'
resampled_data.to_csv(output_file_path, index=False)

output_file_path  # Return the path to the saved CSV file
# Out:
# '/content/resampled_dataset.csv'

# %% [markdown]
# #Genrate Graph dataset from Tabular Dataset (CSV)

# %%
import numpy as np
import pandas as pd

# Load the CSV file into a Pandas DataFrame
df = pd.read_csv('/content/ANsWork - Sheet1 (1).csv')

# Initialize lists to store the row pairs and their correlation coefficients
f_row = []  # List to store the index of the first row in each pair
t_row = []  # List to store the index of the second row in each pair
cor = []    # List to store the correlation coefficient for each pair

# Compute the correlation coefficients for all pairs of rows
for i in range(len(df)):
    for j in range(i+1, len(df)):
        # Calculate the correlation between row i and row j
        correlation = df.iloc[i].corr(df.iloc[j])

        # Store the row indices and their correlation
        f_row.append(i)
        t_row.append(j)
        cor.append(correlation)

# Create a new DataFrame to store the results
corr_df = pd.DataFrame({'target': f_row, 'source': t_row, 'Correlation': cor})

# Print the resulting DataFrame
print(corr_df)

# Increase the row indices by 1 to make them 1-based instead of 0-based
corr_df['source'] = corr_df['source'] + 1
corr_df['target'] = corr_df['target'] + 1

# Print the updated DataFrame of graph dataset
print(corr_df)

# Save the results to a new CSV file
corr_df.to_csv('/content/edge_relationss.csv', index=False)
# Out:
#        target  source  Correlation
# 0           0       1     0.829143
# 1           0       2     0.815515
# 2           0       3     0.790428
# 3           0       4     0.734668
# 4           0       5     0.736824
# ...       ...     ...          ...
# 45446     298     300     0.999997
# 45447     298     301     0.999999
# 45448     299     300     0.999996
# 45449     299     301     0.999998
# 45450     300     301     0.999997
#
# [45451 rows x 3 columns]
#        target  source  Correlation
# 0           1       2     0.829143
# 1           1       3     0.815515
# 2           1       4     0.790428
# 3           1       5     0.734668
# 4           1       6     0.736824
# ...       ...     ...          ...
# 45446     299     301     0.999997
# 45447     299     302     0.999999
# 45448     300     301     0.999996
# 45449     300     302     0.999998
# 45450     301     302     0.999997
#
# [45451 rows x 3 columns]

# %% [markdown]
# #Graph Neural Network Model

# %%
# Importing the necessary libraries
import os
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# Load the graph dataset data from a CSV file into a Pandas DataFrame
Graph_data = pd.read_csv('/content/edge_relationss.csv')

# Print the shape of the DataFrame, which shows the number of rows and columns
print("Graph dataset shape:", Graph_data.shape)
# Out:
# Graph dataset shape: (45451, 3)

# %%
# Print the graph dataset
print(Graph_data)
# Out:
#        target  source  Correlation
# 0           1       2     0.829143
# 1           1       3     0.815515
# 2           1       4     0.790428
# 3           1       5     0.734668
# 4           1       6     0.736824
# ...       ...     ...          ...
# 45446     299     301     0.999997
# 45447     299     302     0.999999
# 45448     300     301     0.999996
# 45449     300     302     0.999998
# 45450     301     302     0.999997
#
# [45451 rows x 3 columns]

# %%
# Define the column names for the Node Feature DataFrame
column_names = ["US_ID"] + [f"term_{idx}" for idx in range(6)] + ["Class_c"] #The line creates a list of column names for a DataFrame, starting with "US_ID" for unique node identifiers, followed by 6 feature columns named "term_0" to "term_5", and ending with "Class_c" for node labels.

# Load the node features data from a CSV file into a Pandas DataFrame
Node_Feature = pd.read_csv('/content/ANsWork - Sheet1 (1).csv')

# Print the shape of the DataFrame, which shows the number of rows and columns
print("Node feature shape:", Node_Feature.shape)
# Out:
# Node feature shape: (302, 8)

# %%
# Print the count of each unique value in the 'Class_c' column of the Node_Feature DataFrame
print(Node_Feature.Class_c.value_counts())
# Out:
# Class_c
# 1    79
# 4    74
# 3    46
# 6    37
# 2    23
# 8    21
# 7    15
# 5     7
# Name: count, dtype: int64

# %%
# Get a sorted list of unique class values from the 'Class_c' column
class_values = sorted(Node_Feature["Class_c"].unique())

# Create a dictionary mapping class names to integer indices
class_idx = {name: id for id, name in enumerate(class_values)}

# Create a dictionary mapping node IDs to integer indices
Node_Feature_idx = {name: idx for idx, name in enumerate(sorted(Node_Feature["US_ID"].unique()))}

# Update the 'US_ID' column to use integer indices instead of original node IDs
Node_Feature["US_ID"] = Node_Feature["US_ID"].apply(lambda name: Node_Feature_idx[name])

# Update the 'source' column in Graph_data to use integer indices instead of original node IDs
Graph_data["source"] = Graph_data["source"].apply(lambda name: Node_Feature_idx[name])

# Update the 'target' column in Graph_data to use integer indices instead of original node IDs
Graph_data["target"] = Graph_data["target"].apply(lambda name: Node_Feature_idx[name])

# Update the 'Class_c' column to use integer indices instead of original class names
Node_Feature["Class_c"] = Node_Feature["Class_c"].apply(lambda value: class_idx[value])

# %%
# Set up the figure size for the plot
plt.figure(figsize=(10, 10))

# Get a list of class labels (colors) for each node from the 'Class_c' column
colors = Node_Feature["Class_c"].tolist()

# Create a graph from a sample of the edges in the Graph_data DataFrame
# Sample 102,383 edges to create the graph
cora_graph = nx.from_pandas_edgelist(Graph_data.sample(n=102383))

# Get the class labels (subjects) for the nodes in the graph
subjects = list(Node_Feature[Node_Feature["US_ID"].isin(list(cora_graph.nodes))]["Class_c"])

# Draw the graph using the spring layout
# Each node is colored according to its class label
nx.draw_spring(cora_graph, node_size=15, node_color=subjects)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-18e7c6fb6c98> in <cell line: 9>()
#       7 # Create a graph from a sample of the edges in the Graph_data DataFrame
#       8 # Sample 102,383 edges to create the graph
# ----> 9 cora_graph = nx.from_pandas_edgelist(Graph_data.sample(n=102383))
#      10
#      11 # Get the class labels (subjects) for the nodes in the graph
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    6027             weights = sample.preprocess_weights(self, weights, axis)
#    6028
# -> 6029         sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    6030         result = self.take(sampled_indices, axis=axis)
#    6031
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/sample.py in sample(obj_len, size, replace, weights, random_state)
#     150             raise ValueError("Invalid weights: weights sum to zero")
#     151
# --> 152     return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     153         np.intp, copy=False
#     154     )
#
# numpy/random/mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %% [markdown]
# #Baseline model (Feed Forward Neural Network)

# %%
# Initialize empty lists to hold the training and test data
train_data, test_data = [], []

# Group the data by the 'Class_c' column and iterate over each group
for _, group_data in Node_Feature.groupby("Class_c"):
    # Randomly select approximately 70% of the data for training
    random_selection = np.random.rand(len(group_data.index)) <= 0.70

    # Append the selected training data to the train_data list
    train_data.append(group_data[random_selection])

    # Append the remaining data to the test_data list
    test_data.append(group_data[~random_selection])

# Concatenate all the training data and shuffle the rows
train_data = pd.concat(train_data).sample(frac=1)

# Concatenate all the test data and shuffle the rows
test_data = pd.concat(test_data).sample(frac=1)

# Print the shape of the training data
print("Train data shape:", train_data.shape)

# Print the shape of the test data
print("Test data shape:", test_data.shape)
# Out:
# Train data shape: (219, 8)
# Test data shape: (83, 8)

# %%
# Define the number of units (neurons) in each hidden layer of the neural network
hidden_units = [64, 64]

# Set the learning rate for the optimizer, which controls how much to change the model in response to the estimated error each time it passes through the network
learning_rate = 0.01

# Specify the dropout rate, which is the fraction of input units to drop during training to prevent overfitting
dropout_rate = 0.3

# Define the number of epochs, which is the number of times the learning algorithm will work through the entire training dataset
num_epochs = 400

# Set the batch size, which is the number of training examples utilized in one iteration
batch_size = 128

# %%
def run_experiment(model, x_train, y_train):
    # Compile the model with specified optimizer, loss function, and metrics
    model.compile(
        optimizer=keras.optimizers.Nadam(learning_rate),  # Optimizer with specified learning rate
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),  # Loss function for sparse categorical targets
        metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],  # Metric to monitor during training
    )

    # Fit the model to the training data
    history = model.fit(
        x=x_train,  # Input features
        y=y_train,  # Target labels
        epochs=num_epochs,  # Number of training epochs
        batch_size=batch_size,  # Number of samples per gradient update
        validation_split=0.15,  # Fraction of training data to use as validation data
    )

    return history  # Return the training history

# %%
def display_learning_curves(history):
    # Create a figure with two subplots side by side
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

    # Plot training and validation loss over epochs
    ax1.plot(history.history["loss"])        # Plot training loss
    ax1.plot(history.history["val_loss"])    # Plot validation loss
    ax1.legend(["train", "test"], loc="upper right")  # Add legend indicating train and test curves
    ax1.set_xlabel("Epochs")                 # Label x-axis
    ax1.set_ylabel("Loss")                   # Label y-axis

    # Plot training and validation accuracy over epochs
    ax2.plot(history.history["acc"])         # Plot training accuracy
    ax2.plot(history.history["val_acc"])     # Plot validation accuracy
    ax2.legend(["train", "test"], loc="upper right")  # Add legend indicating train and test curves
    ax2.set_xlabel("Epochs")                 # Label x-axis
    ax2.set_ylabel("Accuracy")               # Label y-axis

    plt.show()  # Display the plot

    fig.savefig("AUC_LOSS.jpg", dpi=600) #save the plot with 600 dpi

# %%
def create_ffn(hidden_units, dropout_rate, name=None):
    ffn_layers = []  # Initialize an empty list to store layers

    # Loop over each number of units in hidden_units
    for units in hidden_units:
        # Add BatchNormalization layer to normalize and stabilize the inputs to the next layer
        ffn_layers.append(layers.BatchNormalization())

        # Add Dropout layer to prevent overfitting by randomly setting a fraction of input units to 0 during training
        ffn_layers.append(layers.Dropout(dropout_rate))

        # Add Dense layer (fully connected layer) with specified number of units and activation function
        ffn_layers.append(layers.Dense(units, activation=tf.nn.elu))

    # Create a Sequential model from the list of layers
    return keras.Sequential(ffn_layers, name=name)

# %%
feature_names = set(Node_Feature.columns) - {"US_ID", "Class_c"}
'''
1. Node_Feature.columns: Retrieves the column names of the Node_Feature DataFrame.
2. set(Node_Feature.columns): Converts the column names into a set, which contains unique elements (column names).
3. {"US_ID", "Class_c"}: Creates a set with two elements, "US_ID" and "Class_c".
4. set(Node_Feature.columns) - {"US_ID", "Class_c"}: Performs set difference operation, excluding "US_ID" and "Class_c" columns.
5. feature_names: Stores the remaining column names, representing the features of interest.
'''

num_features = len(feature_names) #counts how many columns are considered features.

num_classes = len(class_idx) #counts how many unique classes are present in the dataset, derived from a previously prepared class_idx dictionary.

# %%
# Convert the list of feature names to a list (if it isn't already).
feature_names = list(feature_names)

# Create training features as a numpy array from the training data.
x_train = train_data[feature_names].to_numpy()

# Create testing features as a numpy array from the testing data.
x_test = test_data[feature_names].to_numpy()

# Create training targets (labels) as a numpy array from the training data.
y_train = train_data["Class_c"]

# Create testing targets (labels) as a numpy array from the testing data.
y_test = test_data["Class_c"]

# %%
def create_baseline_model(hidden_units, num_classes, dropout_rate=0.2):
    # Define input layer for the model with shape based on number of features.
    inputs = layers.Input(shape=(num_features,), name="input_features")

    # Create the first feedforward network block using specified hidden units and dropout rate.
    x = create_ffn(hidden_units, dropout_rate, name=f"ffn_block1")(inputs)

    # Loop to create subsequent feedforward network blocks with skip connections.
    for block_idx in range(4):
        # Create two separate feedforward blocks.
        x1 = create_ffn(hidden_units, dropout_rate, name=f"ffn_block{block_idx + 2}")(x)
        x2 = create_ffn(hidden_units, dropout_rate, name=f"ffn_block{block_idx + 6}")(x)

        # Add skip connections: add the original input (x) to each feedforward block output.
        x = layers.Add(name=f"skip_connection{block_idx + 2}")([x, x1])
        x = layers.Add(name=f"skip_connection{block_idx + 6}")([x, x2])

    # Final dense layer to compute logits (output scores) for each class.
    logits = layers.Dense(num_classes, name="logits")(x)

    # Create the Keras model with defined inputs and computed logits as outputs.
    return keras.Model(inputs=inputs, outputs=logits, name="baseline")

# Create the baseline model with specified parameters.
baseline_model = create_baseline_model(hidden_units, num_classes, dropout_rate)

# Print a summary of the model architecture, detailing the layers, output shapes, and number of parameters.
baseline_model.summary()
# Out:
# Model: "baseline"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_features            │ (None, 6)              │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ffn_block1 (Sequential)   │ (None, 64)             │          4,888 │ input_features[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ffn_block2 (Sequential)   │ (None, 64)             │          8,832 │ ffn_block1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ skip_connection2 (Add)    │ (None, 64)             │              0 │ ffn_block1[0][0],      │
# │                           │                        │                │ ffn_block2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ffn_block6 (Sequential)   │ (None, 64)             │          8,832 │ ffn_block1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ skip_connection6 (Add)    │ (None, 64)             │              0 │ skip_connection2[0][0… │
# │                           │                        │                │ ffn_block6[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ffn_block3 (Sequential)   │ (None, 64)             │          8,832 │ skip_connection6[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ skip_connection3 (Add)    │ (None, 64)             │              0 │ skip_connection6[0][0… │
# │                           │                        │                │ ffn_block3[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ffn_block7 (Sequential)   │ (None, 64)             │          8,832 │ skip_connection6[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ skip_connection7 (Add)    │ (None, 64)             │              0 │ skip_connection3[0][0… │
# │                           │                        │                │ ffn_block7[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ffn_block4 (Sequential)   │ (None, 64)             │          8,832 │ skip_connection7[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ skip_connection4 (Add)    │ (None, 64)             │              0 │ skip_connection7[0][0… │
# │                           │                        │                │ ffn_block4[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ffn_block8 (Sequential)   │ (None, 64)             │          8,832 │ skip_connection7[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ skip_connection8 (Add)    │ (None, 64)             │              0 │ skip_connection4[0][0… │
# │                           │                        │                │ ffn_block8[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ffn_block5 (Sequential)   │ (None, 64)             │          8,832 │ skip_connection8[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ skip_connection5 (Add)    │ (None, 64)             │              0 │ skip_connection8[0][0… │
# │                           │                        │                │ ffn_block5[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ffn_block9 (Sequential)   │ (None, 64)             │          8,832 │ skip_connection8[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ skip_connection9 (Add)    │ (None, 64)             │              0 │ skip_connection5[0][0… │
# │                           │                        │                │ ffn_block9[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ logits (Dense)            │ (None, 8)              │            520 │ skip_connection9[0][0] │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 76,064 (297.12 KB)
#  Trainable params: 73,876 (288.58 KB)
#  Non-trainable params: 2,188 (8.55 KB)

# %%
# Run an experiment using a baseline model with the node feature dataframe's training instances
history = run_experiment(baseline_model, x_train, y_train)
# Out:
# Epoch 1/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 43s 15s/step - acc: 0.1538 - loss: 5.3235 - val_acc: 0.3030 - val_loss: 2.6454
# Epoch 2/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - acc: 0.2450 - loss: 3.6092 - val_acc: 0.3030 - val_loss: 2.4664
# Epoch 3/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.2482 - loss: 3.5589 - val_acc: 0.3333 - val_loss: 2.3471
# Epoch 4/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.3332 - loss: 2.8996 - val_acc: 0.2424 - val_loss: 2.1560
# Epoch 5/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - acc: 0.3270 - loss: 2.6836 - val_acc: 0.3030 - val_loss: 2.0041
# Epoch 6/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.2642 - loss: 2.7085 - val_acc: 0.2424 - val_loss: 1.9587
# Epoch 7/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.3280 - loss: 2.6466 - val_acc: 0.2727 - val_loss: 1.8438
# Epoch 8/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.2720 - loss: 2.6280 - val_acc: 0.2424 - val_loss: 2.5066
# Epoch 9/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.2756 - loss: 2.7729 - val_acc: 0.2121 - val_loss: 2.1139
# Epoch 10/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.3114 - loss: 2.2826 - val_acc: 0.2121 - val_loss: 1.9446
# Epoch 11/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.3547 - loss: 2.4167 - val_acc: 0.2121 - val_loss: 2.0447
# Epoch 12/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.3668 - loss: 2.0936 - val_acc: 0.2121 - val_loss: 2.3005
# Epoch 13/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.3124 - loss: 2.0560 - val_acc: 0.2424 - val_loss: 2.1370
# Epoch 14/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.3498 - loss: 2.1334 - val_acc: 0.3333 - val_loss: 2.3474
# Epoch 15/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.3336 - loss: 2.0082 - val_acc: 0.2727 - val_loss: 2.1760
# Epoch 16/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 0.2964 - loss: 2.1457 - val_acc: 0.2121 - val_loss: 1.9663
# Epoch 17/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.3925 - loss: 1.9741 - val_acc: 0.2727 - val_loss: 2.2389
# Epoch 18/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.3521 - loss: 2.2585 - val_acc: 0.1818 - val_loss: 2.0832
# Epoch 19/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.3336 - loss: 2.0171 - val_acc: 0.2121 - val_loss: 1.9620
# Epoch 20/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.3466 - loss: 1.8801 - val_acc: 0.2424 - val_loss: 1.9052
# Epoch 21/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.3635 - loss: 1.9402 - val_acc: 0.2424 - val_loss: 1.9769
# Epoch 22/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4388 - loss: 1.7001 - val_acc: 0.2727 - val_loss: 1.9183
# Epoch 23/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 0.3368 - loss: 1.8792 - val_acc: 0.2424 - val_loss: 1.8496
# Epoch 24/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - acc: 0.3635 - loss: 1.9176 - val_acc: 0.3939 - val_loss: 1.8994
# Epoch 25/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.3547 - loss: 1.9359 - val_acc: 0.2424 - val_loss: 1.9846
# Epoch 26/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.3616 - loss: 1.8455 - val_acc: 0.3333 - val_loss: 1.8847
# Epoch 27/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.3590 - loss: 1.7663 - val_acc: 0.2727 - val_loss: 1.9029
# Epoch 28/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.3609 - loss: 1.7378 - val_acc: 0.1818 - val_loss: 1.9736
# Epoch 29/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.3573 - loss: 1.7649 - val_acc: 0.1818 - val_loss: 2.0160
# Epoch 30/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.3775 - loss: 1.7711 - val_acc: 0.3030 - val_loss: 1.9378
# Epoch 31/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.3296 - loss: 1.9328 - val_acc: 0.2727 - val_loss: 1.9568
# Epoch 32/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.3583 - loss: 1.6979 - val_acc: 0.2424 - val_loss: 1.9698
# Epoch 33/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.3450 - loss: 1.7030 - val_acc: 0.2121 - val_loss: 2.0381
# Epoch 34/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.3876 - loss: 1.6989 - val_acc: 0.2121 - val_loss: 2.0835
# Epoch 35/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - acc: 0.3661 - loss: 1.6659 - val_acc: 0.2727 - val_loss: 1.9643
# Epoch 36/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 0.3658 - loss: 1.6676 - val_acc: 0.3030 - val_loss: 2.0168
# Epoch 37/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.3104 - loss: 1.7001 - val_acc: 0.2727 - val_loss: 1.9755
# Epoch 38/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.3873 - loss: 1.6902 - val_acc: 0.2121 - val_loss: 1.9122
# Epoch 39/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4196 - loss: 1.6138 - val_acc: 0.3030 - val_loss: 1.9159
# Epoch 40/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.3264 - loss: 1.7397 - val_acc: 0.2727 - val_loss: 1.8593
# Epoch 41/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4228 - loss: 1.5476 - val_acc: 0.2727 - val_loss: 1.8824
# Epoch 42/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4182 - loss: 1.5578 - val_acc: 0.3030 - val_loss: 1.9470
# Epoch 43/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 0.4052 - loss: 1.5999 - val_acc: 0.3030 - val_loss: 1.8282
# Epoch 44/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.5140 - loss: 1.4242 - val_acc: 0.4242 - val_loss: 1.7984
# Epoch 45/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.3505 - loss: 1.7493 - val_acc: 0.4242 - val_loss: 1.7828
# Epoch 46/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4192 - loss: 1.5442 - val_acc: 0.3333 - val_loss: 1.7974
# Epoch 47/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4254 - loss: 1.5678 - val_acc: 0.3333 - val_loss: 1.8243
# Epoch 48/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.3590 - loss: 1.6255 - val_acc: 0.2727 - val_loss: 1.8045
# Epoch 49/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.3476 - loss: 1.6091 - val_acc: 0.3636 - val_loss: 1.7717
# Epoch 50/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - acc: 0.4140 - loss: 1.5749 - val_acc: 0.3636 - val_loss: 1.7635
# Epoch 51/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.3687 - loss: 1.6399 - val_acc: 0.3939 - val_loss: 1.7725
# Epoch 52/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4440 - loss: 1.5875 - val_acc: 0.4545 - val_loss: 1.7751
# Epoch 53/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4016 - loss: 1.5362 - val_acc: 0.4545 - val_loss: 1.8137
# Epoch 54/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4316 - loss: 1.4897 - val_acc: 0.3939 - val_loss: 1.8185
# Epoch 55/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.4401 - loss: 1.5710 - val_acc: 0.3030 - val_loss: 1.8724
# Epoch 56/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4173 - loss: 1.5336 - val_acc: 0.3333 - val_loss: 1.8860
# Epoch 57/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.3769 - loss: 1.5742 - val_acc: 0.2727 - val_loss: 1.9289
# Epoch 58/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.4085 - loss: 1.5710 - val_acc: 0.3030 - val_loss: 1.9163
# Epoch 59/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4166 - loss: 1.6355 - val_acc: 0.2424 - val_loss: 1.8339
# Epoch 60/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 0.4388 - loss: 1.5623 - val_acc: 0.3030 - val_loss: 1.8302
# Epoch 61/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.4042 - loss: 1.5453 - val_acc: 0.3333 - val_loss: 1.8108
# Epoch 62/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.3902 - loss: 1.5011 - val_acc: 0.3333 - val_loss: 1.8113
# Epoch 63/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4521 - loss: 1.4916 - val_acc: 0.3333 - val_loss: 1.7709
# Epoch 64/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.3928 - loss: 1.4775 - val_acc: 0.3636 - val_loss: 1.7362
# Epoch 65/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.3964 - loss: 1.5399 - val_acc: 0.4242 - val_loss: 1.7390
# Epoch 66/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - acc: 0.4440 - loss: 1.4863 - val_acc: 0.2121 - val_loss: 1.7759
# Epoch 67/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.4085 - loss: 1.5325 - val_acc: 0.2424 - val_loss: 1.7957
# Epoch 68/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.4459 - loss: 1.5142 - val_acc: 0.2727 - val_loss: 1.8525
# Epoch 69/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4707 - loss: 1.4709 - val_acc: 0.2424 - val_loss: 1.9242
# Epoch 70/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.4228 - loss: 1.5093 - val_acc: 0.2727 - val_loss: 1.9354
# Epoch 71/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - acc: 0.4186 - loss: 1.5188 - val_acc: 0.2424 - val_loss: 1.9293
# Epoch 72/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.4404 - loss: 1.4688 - val_acc: 0.2727 - val_loss: 1.8690
# Epoch 73/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.3997 - loss: 1.4988 - val_acc: 0.3030 - val_loss: 1.8378
# Epoch 74/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4202 - loss: 1.5265 - val_acc: 0.3030 - val_loss: 1.7868
# Epoch 75/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.3394 - loss: 1.6817 - val_acc: 0.3030 - val_loss: 1.7271
# Epoch 76/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4270 - loss: 1.5133 - val_acc: 0.3939 - val_loss: 1.6783
# Epoch 77/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4313 - loss: 1.4995 - val_acc: 0.4242 - val_loss: 1.6811
# Epoch 78/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.4563 - loss: 1.4075 - val_acc: 0.3939 - val_loss: 1.6927
# Epoch 79/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4329 - loss: 1.4738 - val_acc: 0.3939 - val_loss: 1.6528
# Epoch 80/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4769 - loss: 1.4724 - val_acc: 0.3636 - val_loss: 1.6720
# Epoch 81/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.4267 - loss: 1.5528 - val_acc: 0.3030 - val_loss: 1.7005
# Epoch 82/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4274 - loss: 1.5450 - val_acc: 0.3333 - val_loss: 1.6900
# Epoch 83/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4414 - loss: 1.4399 - val_acc: 0.4848 - val_loss: 1.6746
# Epoch 84/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.4573 - loss: 1.4508 - val_acc: 0.4545 - val_loss: 1.6526
# Epoch 85/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.4140 - loss: 1.4382 - val_acc: 0.4545 - val_loss: 1.6868
# Epoch 86/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4336 - loss: 1.3941 - val_acc: 0.4545 - val_loss: 1.7161
# Epoch 87/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.4274 - loss: 1.4779 - val_acc: 0.3939 - val_loss: 1.7511
# Epoch 88/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4511 - loss: 1.4676 - val_acc: 0.2727 - val_loss: 1.7837
# Epoch 89/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.5042 - loss: 1.3759 - val_acc: 0.3030 - val_loss: 1.8094
# Epoch 90/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.4202 - loss: 1.4957 - val_acc: 0.3333 - val_loss: 1.7642
# Epoch 91/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4365 - loss: 1.4738 - val_acc: 0.3333 - val_loss: 1.7288
# Epoch 92/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4394 - loss: 1.4117 - val_acc: 0.3939 - val_loss: 1.6698
# Epoch 93/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4186 - loss: 1.4895 - val_acc: 0.3939 - val_loss: 1.6448
# Epoch 94/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.4013 - loss: 1.5340 - val_acc: 0.4242 - val_loss: 1.6376
# Epoch 95/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - acc: 0.4130 - loss: 1.3829 - val_acc: 0.3636 - val_loss: 1.6453
# Epoch 96/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - acc: 0.4469 - loss: 1.4758 - val_acc: 0.3636 - val_loss: 1.7015
# Epoch 97/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.3831 - loss: 1.5277 - val_acc: 0.3636 - val_loss: 1.7173
# Epoch 98/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4485 - loss: 1.3570 - val_acc: 0.3636 - val_loss: 1.7375
# Epoch 99/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4274 - loss: 1.4930 - val_acc: 0.2727 - val_loss: 1.7271
# Epoch 100/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4547 - loss: 1.3693 - val_acc: 0.2727 - val_loss: 1.7376
# Epoch 101/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4260 - loss: 1.4670 - val_acc: 0.2727 - val_loss: 1.6699
# Epoch 102/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4212 - loss: 1.4923 - val_acc: 0.3636 - val_loss: 1.6871
# Epoch 103/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - acc: 0.4603 - loss: 1.4052 - val_acc: 0.3939 - val_loss: 1.7111
# Epoch 104/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4329 - loss: 1.4913 - val_acc: 0.3636 - val_loss: 1.7048
# Epoch 105/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4449 - loss: 1.4784 - val_acc: 0.3636 - val_loss: 1.6912
# Epoch 106/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.4274 - loss: 1.4718 - val_acc: 0.4848 - val_loss: 1.6835
# Epoch 107/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 0.4583 - loss: 1.4264 - val_acc: 0.3636 - val_loss: 1.6696
# Epoch 108/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4697 - loss: 1.3888 - val_acc: 0.3030 - val_loss: 1.6894
# Epoch 109/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - acc: 0.4059 - loss: 1.4976 - val_acc: 0.2121 - val_loss: 1.7163
# Epoch 110/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - acc: 0.3788 - loss: 1.4781 - val_acc: 0.2121 - val_loss: 1.7078
# Epoch 111/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 0.4078 - loss: 1.5252 - val_acc: 0.2424 - val_loss: 1.7059
# Epoch 112/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 0.4042 - loss: 1.4654 - val_acc: 0.2727 - val_loss: 1.7165
# Epoch 113/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - acc: 0.4248 - loss: 1.4084 - val_acc: 0.3636 - val_loss: 1.6994
# Epoch 114/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - acc: 0.4511 - loss: 1.4089 - val_acc: 0.3636 - val_loss: 1.6616
# Epoch 115/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - acc: 0.4528 - loss: 1.4344 - val_acc: 0.4848 - val_loss: 1.6315
# Epoch 116/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 0.4443 - loss: 1.3904 - val_acc: 0.3939 - val_loss: 1.6154
# Epoch 117/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - acc: 0.4948 - loss: 1.3618 - val_acc: 0.3636 - val_loss: 1.5517
# Epoch 118/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - acc: 0.4687 - loss: 1.5117 - val_acc: 0.3636 - val_loss: 1.5695
# Epoch 119/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - acc: 0.4234 - loss: 1.4561 - val_acc: 0.3939 - val_loss: 1.6111
# Epoch 120/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - acc: 0.4489 - loss: 1.4591 - val_acc: 0.3939 - val_loss: 1.6567
# Epoch 121/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - acc: 0.4537 - loss: 1.3915 - val_acc: 0.4242 - val_loss: 1.6695
# Epoch 122/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 0.4697 - loss: 1.3630 - val_acc: 0.4242 - val_loss: 1.7126
# Epoch 123/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - acc: 0.4785 - loss: 1.4339 - val_acc: 0.3636 - val_loss: 1.7772
# Epoch 124/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - acc: 0.4391 - loss: 1.4721 - val_acc: 0.3333 - val_loss: 1.8274
# Epoch 125/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - acc: 0.3889 - loss: 1.5131 - val_acc: 0.3030 - val_loss: 1.8016
# Epoch 126/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - acc: 0.4609 - loss: 1.3868 - val_acc: 0.4242 - val_loss: 1.7714
# Epoch 127/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4997 - loss: 1.4123 - val_acc: 0.3939 - val_loss: 1.7169
# Epoch 128/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4638 - loss: 1.3843 - val_acc: 0.3636 - val_loss: 1.6521
# Epoch 129/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4160 - loss: 1.4729 - val_acc: 0.3636 - val_loss: 1.5829
# Epoch 130/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4296 - loss: 1.4794 - val_acc: 0.3939 - val_loss: 1.5323
# Epoch 131/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4023 - loss: 1.4723 - val_acc: 0.3939 - val_loss: 1.5378
# Epoch 132/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - acc: 0.4319 - loss: 1.4383 - val_acc: 0.3636 - val_loss: 1.5969
# Epoch 133/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 0.4300 - loss: 1.4502 - val_acc: 0.3636 - val_loss: 1.6590
# Epoch 134/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.4414 - loss: 1.4280 - val_acc: 0.3636 - val_loss: 1.7314
# Epoch 135/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.4042 - loss: 1.4917 - val_acc: 0.3636 - val_loss: 1.7080
# Epoch 136/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4456 - loss: 1.4206 - val_acc: 0.3939 - val_loss: 1.6639
# Epoch 137/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.4609 - loss: 1.4108 - val_acc: 0.4242 - val_loss: 1.6388
# Epoch 138/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4749 - loss: 1.3529 - val_acc: 0.3636 - val_loss: 1.6814
# Epoch 139/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4342 - loss: 1.4756 - val_acc: 0.4545 - val_loss: 1.6729
# Epoch 140/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4336 - loss: 1.4227 - val_acc: 0.3939 - val_loss: 1.6763
# Epoch 141/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.4609 - loss: 1.4354 - val_acc: 0.3939 - val_loss: 1.6381
# Epoch 142/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.3990 - loss: 1.4831 - val_acc: 0.4848 - val_loss: 1.5976
# Epoch 143/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.4264 - loss: 1.4210 - val_acc: 0.4545 - val_loss: 1.5972
# Epoch 144/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 0.4814 - loss: 1.3327 - val_acc: 0.3939 - val_loss: 1.6274
# Epoch 145/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - acc: 0.3994 - loss: 1.5191 - val_acc: 0.3939 - val_loss: 1.6598
# Epoch 146/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 0.4186 - loss: 1.4633 - val_acc: 0.4242 - val_loss: 1.6350
# Epoch 147/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4629 - loss: 1.4114 - val_acc: 0.3333 - val_loss: 1.6179
# Epoch 148/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4244 - loss: 1.4574 - val_acc: 0.3333 - val_loss: 1.5748
# Epoch 149/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4521 - loss: 1.4151 - val_acc: 0.3030 - val_loss: 1.5649
# Epoch 150/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4632 - loss: 1.3712 - val_acc: 0.3636 - val_loss: 1.5685
# Epoch 151/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4511 - loss: 1.3972 - val_acc: 0.3939 - val_loss: 1.5654
# Epoch 152/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4368 - loss: 1.4109 - val_acc: 0.3939 - val_loss: 1.6088
# Epoch 153/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - acc: 0.4821 - loss: 1.3907 - val_acc: 0.3636 - val_loss: 1.6630
# Epoch 154/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - acc: 0.4638 - loss: 1.3634 - val_acc: 0.3636 - val_loss: 1.6508
# Epoch 155/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 0.4336 - loss: 1.5038 - val_acc: 0.3333 - val_loss: 1.6361
# Epoch 156/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4274 - loss: 1.4421 - val_acc: 0.3333 - val_loss: 1.6293
# Epoch 157/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4147 - loss: 1.5539 - val_acc: 0.3333 - val_loss: 1.6551
# Epoch 158/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4671 - loss: 1.3623 - val_acc: 0.3333 - val_loss: 1.6273
# Epoch 159/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4222 - loss: 1.4552 - val_acc: 0.3636 - val_loss: 1.6253
# Epoch 160/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4609 - loss: 1.4970 - val_acc: 0.4242 - val_loss: 1.5461
# Epoch 161/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.3980 - loss: 1.4650 - val_acc: 0.3636 - val_loss: 1.5798
# Epoch 162/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4743 - loss: 1.4133 - val_acc: 0.3939 - val_loss: 1.6235
# Epoch 163/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - acc: 0.4300 - loss: 1.4928 - val_acc: 0.3939 - val_loss: 1.6281
# Epoch 164/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4583 - loss: 1.4086 - val_acc: 0.3636 - val_loss: 1.6132
# Epoch 165/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - acc: 0.4062 - loss: 1.5395 - val_acc: 0.4242 - val_loss: 1.6317
# Epoch 166/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.4238 - loss: 1.4679 - val_acc: 0.3939 - val_loss: 1.6115
# Epoch 167/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4883 - loss: 1.4211 - val_acc: 0.3939 - val_loss: 1.5811
# Epoch 168/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4769 - loss: 1.3589 - val_acc: 0.3636 - val_loss: 1.6475
# Epoch 169/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.4700 - loss: 1.3953 - val_acc: 0.3636 - val_loss: 1.6445
# Epoch 170/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.4902 - loss: 1.3480 - val_acc: 0.3333 - val_loss: 1.6378
# Epoch 171/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4583 - loss: 1.4188 - val_acc: 0.3636 - val_loss: 1.6241
# Epoch 172/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.4554 - loss: 1.4389 - val_acc: 0.4242 - val_loss: 1.6475
# Epoch 173/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.4306 - loss: 1.3633 - val_acc: 0.3939 - val_loss: 1.6212
# Epoch 174/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4485 - loss: 1.4016 - val_acc: 0.3939 - val_loss: 1.6045
# Epoch 175/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.4537 - loss: 1.4139 - val_acc: 0.2727 - val_loss: 1.6638
# Epoch 176/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - acc: 0.4290 - loss: 1.4462 - val_acc: 0.3333 - val_loss: 1.7441
# Epoch 177/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - acc: 0.4309 - loss: 1.4599 - val_acc: 0.3030 - val_loss: 1.7841
# Epoch 178/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.4010 - loss: 1.4431 - val_acc: 0.3636 - val_loss: 1.8256
# Epoch 179/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4238 - loss: 1.4569 - val_acc: 0.3333 - val_loss: 1.8867
# Epoch 180/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.4511 - loss: 1.4387 - val_acc: 0.3636 - val_loss: 1.8330
# Epoch 181/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.4717 - loss: 1.3743 - val_acc: 0.3333 - val_loss: 1.7841
# Epoch 182/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4814 - loss: 1.3762 - val_acc: 0.3636 - val_loss: 1.6913
# Epoch 183/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.4752 - loss: 1.4443 - val_acc: 0.4242 - val_loss: 1.5812
# Epoch 184/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 0.4300 - loss: 1.4522 - val_acc: 0.5152 - val_loss: 1.4939
# Epoch 185/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.4805 - loss: 1.3486 - val_acc: 0.3939 - val_loss: 1.5239
# Epoch 186/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.4414 - loss: 1.3673 - val_acc: 0.3636 - val_loss: 1.5250
# Epoch 187/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4264 - loss: 1.4539 - val_acc: 0.3939 - val_loss: 1.5339
# Epoch 188/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4622 - loss: 1.4421 - val_acc: 0.3636 - val_loss: 1.6301
# Epoch 189/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4283 - loss: 1.4380 - val_acc: 0.3333 - val_loss: 1.6674
# Epoch 190/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4795 - loss: 1.4230 - val_acc: 0.3636 - val_loss: 1.6850
# Epoch 191/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.5355 - loss: 1.2537 - val_acc: 0.3939 - val_loss: 1.7464
# Epoch 192/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4739 - loss: 1.4039 - val_acc: 0.3636 - val_loss: 1.7508
# Epoch 193/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4541 - loss: 1.3357 - val_acc: 0.3636 - val_loss: 1.7588
# Epoch 194/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4717 - loss: 1.3945 - val_acc: 0.3636 - val_loss: 1.7925
# Epoch 195/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - acc: 0.4453 - loss: 1.4424 - val_acc: 0.3636 - val_loss: 1.7431
# Epoch 196/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - acc: 0.4423 - loss: 1.3939 - val_acc: 0.3636 - val_loss: 1.7032
# Epoch 197/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4583 - loss: 1.3849 - val_acc: 0.3333 - val_loss: 1.6703
# Epoch 198/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4531 - loss: 1.3581 - val_acc: 0.3333 - val_loss: 1.6417
# Epoch 199/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4124 - loss: 1.4696 - val_acc: 0.3333 - val_loss: 1.5868
# Epoch 200/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4671 - loss: 1.4221 - val_acc: 0.3939 - val_loss: 1.6113
# Epoch 201/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4674 - loss: 1.3867 - val_acc: 0.4242 - val_loss: 1.5917
# Epoch 202/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4449 - loss: 1.3909 - val_acc: 0.4242 - val_loss: 1.5743
# Epoch 203/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4521 - loss: 1.3707 - val_acc: 0.4242 - val_loss: 1.5974
# Epoch 204/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4417 - loss: 1.4904 - val_acc: 0.3939 - val_loss: 1.6169
# Epoch 205/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4355 - loss: 1.3642 - val_acc: 0.3939 - val_loss: 1.6701
# Epoch 206/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4316 - loss: 1.3888 - val_acc: 0.3636 - val_loss: 1.6978
# Epoch 207/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4573 - loss: 1.4546 - val_acc: 0.3636 - val_loss: 1.7356
# Epoch 208/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 0.4423 - loss: 1.4308 - val_acc: 0.3636 - val_loss: 1.7449
# Epoch 209/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.4866 - loss: 1.2784 - val_acc: 0.3939 - val_loss: 1.7297
# Epoch 210/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.4857 - loss: 1.3304 - val_acc: 0.3939 - val_loss: 1.6902
# Epoch 211/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.5274 - loss: 1.2797 - val_acc: 0.3636 - val_loss: 1.6534
# Epoch 212/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4645 - loss: 1.4153 - val_acc: 0.3333 - val_loss: 1.6376
# Epoch 213/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.5016 - loss: 1.3019 - val_acc: 0.3636 - val_loss: 1.6106
# Epoch 214/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4645 - loss: 1.3940 - val_acc: 0.4242 - val_loss: 1.6022
# Epoch 215/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4254 - loss: 1.4609 - val_acc: 0.3636 - val_loss: 1.6464
# Epoch 216/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4485 - loss: 1.4547 - val_acc: 0.3636 - val_loss: 1.6477
# Epoch 217/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4723 - loss: 1.4009 - val_acc: 0.3333 - val_loss: 1.6244
# Epoch 218/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4414 - loss: 1.3689 - val_acc: 0.3333 - val_loss: 1.6330
# Epoch 219/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.4521 - loss: 1.3025 - val_acc: 0.3636 - val_loss: 1.6664
# Epoch 220/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4404 - loss: 1.3339 - val_acc: 0.3636 - val_loss: 1.6559
# Epoch 221/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - acc: 0.4811 - loss: 1.3585 - val_acc: 0.3333 - val_loss: 1.6620
# Epoch 222/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 0.4713 - loss: 1.3887 - val_acc: 0.3030 - val_loss: 1.6500
# Epoch 223/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.5114 - loss: 1.3587 - val_acc: 0.3333 - val_loss: 1.6300
# Epoch 224/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.4557 - loss: 1.3656 - val_acc: 0.3939 - val_loss: 1.6704
# Epoch 225/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.5016 - loss: 1.3541 - val_acc: 0.3939 - val_loss: 1.7211
# Epoch 226/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.5221 - loss: 1.3504 - val_acc: 0.3939 - val_loss: 1.6862
# Epoch 227/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4788 - loss: 1.3403 - val_acc: 0.3636 - val_loss: 1.7161
# Epoch 228/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4857 - loss: 1.3961 - val_acc: 0.4242 - val_loss: 1.6710
# Epoch 229/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4417 - loss: 1.4287 - val_acc: 0.4242 - val_loss: 1.6836
# Epoch 230/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4795 - loss: 1.3686 - val_acc: 0.4242 - val_loss: 1.6496
# Epoch 231/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4495 - loss: 1.4194 - val_acc: 0.3333 - val_loss: 1.7346
# Epoch 232/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4661 - loss: 1.3995 - val_acc: 0.3333 - val_loss: 1.7479
# Epoch 233/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - acc: 0.4759 - loss: 1.3364 - val_acc: 0.3939 - val_loss: 1.6260
# Epoch 234/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 0.4681 - loss: 1.3976 - val_acc: 0.4242 - val_loss: 1.6281
# Epoch 235/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4388 - loss: 1.4076 - val_acc: 0.4242 - val_loss: 1.6124
# Epoch 236/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.4866 - loss: 1.3655 - val_acc: 0.4545 - val_loss: 1.5822
# Epoch 237/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4902 - loss: 1.3253 - val_acc: 0.4242 - val_loss: 1.5630
# Epoch 238/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - acc: 0.4671 - loss: 1.4192 - val_acc: 0.3939 - val_loss: 1.5526
# Epoch 239/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - acc: 0.4326 - loss: 1.4279 - val_acc: 0.3333 - val_loss: 1.5647
# Epoch 240/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 0.4671 - loss: 1.3114 - val_acc: 0.3636 - val_loss: 1.5543
# Epoch 241/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - acc: 0.4779 - loss: 1.4237 - val_acc: 0.3939 - val_loss: 1.5396
# Epoch 242/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - acc: 0.4388 - loss: 1.4350 - val_acc: 0.4545 - val_loss: 1.4943
# Epoch 243/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - acc: 0.4681 - loss: 1.3438 - val_acc: 0.4848 - val_loss: 1.5179
# Epoch 244/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 0.4837 - loss: 1.3005 - val_acc: 0.4242 - val_loss: 1.6069
# Epoch 245/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - acc: 0.4257 - loss: 1.4542 - val_acc: 0.3939 - val_loss: 1.6668
# Epoch 246/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - acc: 0.4160 - loss: 1.3866 - val_acc: 0.3636 - val_loss: 1.6526
# Epoch 247/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 0.4840 - loss: 1.4132 - val_acc: 0.4242 - val_loss: 1.6704
# Epoch 248/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - acc: 0.4319 - loss: 1.3777 - val_acc: 0.3939 - val_loss: 1.7368
# Epoch 249/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - acc: 0.4443 - loss: 1.4071 - val_acc: 0.3939 - val_loss: 1.7113
# Epoch 250/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - acc: 0.4909 - loss: 1.3690 - val_acc: 0.3939 - val_loss: 1.6785
# Epoch 251/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - acc: 0.4655 - loss: 1.3242 - val_acc: 0.3636 - val_loss: 1.6820
# Epoch 252/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - acc: 0.4199 - loss: 1.4654 - val_acc: 0.3636 - val_loss: 1.6528
# Epoch 253/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - acc: 0.5362 - loss: 1.3207 - val_acc: 0.3939 - val_loss: 1.6076
# Epoch 254/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - acc: 0.4593 - loss: 1.3705 - val_acc: 0.3636 - val_loss: 1.5843
# Epoch 255/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - acc: 0.4665 - loss: 1.3345 - val_acc: 0.2727 - val_loss: 1.5879
# Epoch 256/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - acc: 0.4140 - loss: 1.5337 - val_acc: 0.3333 - val_loss: 1.6451
# Epoch 257/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - acc: 0.4814 - loss: 1.3777 - val_acc: 0.3030 - val_loss: 1.5692
# Epoch 258/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - acc: 0.4000 - loss: 1.4525 - val_acc: 0.4242 - val_loss: 1.5420
# Epoch 259/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - acc: 0.4404 - loss: 1.4175 - val_acc: 0.4545 - val_loss: 1.4983
# Epoch 260/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 0.4485 - loss: 1.3767 - val_acc: 0.4545 - val_loss: 1.4928
# Epoch 261/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4707 - loss: 1.3581 - val_acc: 0.3636 - val_loss: 1.5477
# Epoch 262/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4655 - loss: 1.2997 - val_acc: 0.3636 - val_loss: 1.5995
# Epoch 263/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4619 - loss: 1.3772 - val_acc: 0.3636 - val_loss: 1.6554
# Epoch 264/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.4404 - loss: 1.3947 - val_acc: 0.3030 - val_loss: 1.7219
# Epoch 265/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4244 - loss: 1.3527 - val_acc: 0.3636 - val_loss: 1.7524
# Epoch 266/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.5049 - loss: 1.3268 - val_acc: 0.3939 - val_loss: 1.7767
# Epoch 267/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4645 - loss: 1.4117 - val_acc: 0.3333 - val_loss: 1.8217
# Epoch 268/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 0.4567 - loss: 1.3418 - val_acc: 0.3939 - val_loss: 1.8149
# Epoch 269/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4788 - loss: 1.3542 - val_acc: 0.3939 - val_loss: 1.7990
# Epoch 270/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.4788 - loss: 1.2764 - val_acc: 0.3939 - val_loss: 1.7721
# Epoch 271/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.5062 - loss: 1.3461 - val_acc: 0.3939 - val_loss: 1.7540
# Epoch 272/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4469 - loss: 1.3833 - val_acc: 0.4242 - val_loss: 1.7368
# Epoch 273/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.5443 - loss: 1.2513 - val_acc: 0.3636 - val_loss: 1.7581
# Epoch 274/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4583 - loss: 1.3493 - val_acc: 0.3333 - val_loss: 1.7901
# Epoch 275/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4759 - loss: 1.3200 - val_acc: 0.3333 - val_loss: 1.8543
# Epoch 276/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4114 - loss: 1.3892 - val_acc: 0.3333 - val_loss: 1.8410
# Epoch 277/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.3893 - loss: 1.4627 - val_acc: 0.2727 - val_loss: 1.7890
# Epoch 278/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4388 - loss: 1.3613 - val_acc: 0.3030 - val_loss: 1.8217
# Epoch 279/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.4743 - loss: 1.3730 - val_acc: 0.3030 - val_loss: 1.8816
# Epoch 280/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 0.4743 - loss: 1.4037 - val_acc: 0.3333 - val_loss: 1.7623
# Epoch 281/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.4186 - loss: 1.3955 - val_acc: 0.3333 - val_loss: 1.6681
# Epoch 282/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.4557 - loss: 1.3204 - val_acc: 0.3636 - val_loss: 1.6488
# Epoch 283/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4726 - loss: 1.3659 - val_acc: 0.3939 - val_loss: 1.7159
# Epoch 284/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.4886 - loss: 1.4238 - val_acc: 0.3030 - val_loss: 1.7574
# Epoch 285/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4717 - loss: 1.3996 - val_acc: 0.3333 - val_loss: 1.7327
# Epoch 286/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.5521 - loss: 1.2448 - val_acc: 0.4242 - val_loss: 1.6766
# Epoch 287/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4876 - loss: 1.3427 - val_acc: 0.3939 - val_loss: 1.6804
# Epoch 288/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4173 - loss: 1.4669 - val_acc: 0.4242 - val_loss: 1.6387
# Epoch 289/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.4345 - loss: 1.4515 - val_acc: 0.4545 - val_loss: 1.6755
# Epoch 290/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 0.4371 - loss: 1.3892 - val_acc: 0.3939 - val_loss: 1.6907
# Epoch 291/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 0.4541 - loss: 1.3459 - val_acc: 0.4242 - val_loss: 1.7143
# Epoch 292/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - acc: 0.4733 - loss: 1.3865 - val_acc: 0.4242 - val_loss: 1.6679
# Epoch 293/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - acc: 0.4557 - loss: 1.3453 - val_acc: 0.3333 - val_loss: 1.6423
# Epoch 294/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.5006 - loss: 1.3343 - val_acc: 0.2727 - val_loss: 1.6218
# Epoch 295/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 0.4733 - loss: 1.3974 - val_acc: 0.3030 - val_loss: 1.7403
# Epoch 296/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4068 - loss: 1.4178 - val_acc: 0.3636 - val_loss: 1.7526
# Epoch 297/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.5088 - loss: 1.3352 - val_acc: 0.4242 - val_loss: 1.7111
# Epoch 298/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.4309 - loss: 1.4299 - val_acc: 0.3333 - val_loss: 1.7401
# Epoch 299/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.5072 - loss: 1.3133 - val_acc: 0.2727 - val_loss: 1.8124
# Epoch 300/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - acc: 0.4717 - loss: 1.3761 - val_acc: 0.2424 - val_loss: 1.9977
# Epoch 301/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - acc: 0.4990 - loss: 1.3435 - val_acc: 0.2727 - val_loss: 1.9186
# Epoch 302/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 0.5068 - loss: 1.3515 - val_acc: 0.2121 - val_loss: 1.9012
# Epoch 303/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4795 - loss: 1.3830 - val_acc: 0.2727 - val_loss: 1.8373
# Epoch 304/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4449 - loss: 1.3662 - val_acc: 0.3333 - val_loss: 1.8068
# Epoch 305/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4603 - loss: 1.3627 - val_acc: 0.2727 - val_loss: 1.8975
# Epoch 306/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.4078 - loss: 1.4092 - val_acc: 0.2727 - val_loss: 1.8006
# Epoch 307/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.4687 - loss: 1.3153 - val_acc: 0.2424 - val_loss: 1.7859
# Epoch 308/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4717 - loss: 1.3119 - val_acc: 0.3636 - val_loss: 1.7808
# Epoch 309/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4466 - loss: 1.3553 - val_acc: 0.3939 - val_loss: 1.7522
# Epoch 310/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4404 - loss: 1.2736 - val_acc: 0.3636 - val_loss: 1.7265
# Epoch 311/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 0.4645 - loss: 1.3822 - val_acc: 0.3636 - val_loss: 1.6956
# Epoch 312/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4319 - loss: 1.4601 - val_acc: 0.3939 - val_loss: 1.7251
# Epoch 313/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.5345 - loss: 1.2982 - val_acc: 0.3030 - val_loss: 1.7577
# Epoch 314/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.4866 - loss: 1.3391 - val_acc: 0.3030 - val_loss: 1.7214
# Epoch 315/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.5000 - loss: 1.3880 - val_acc: 0.3333 - val_loss: 1.6964
# Epoch 316/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 0.4687 - loss: 1.4015 - val_acc: 0.3333 - val_loss: 1.7256
# Epoch 317/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.4300 - loss: 1.3910 - val_acc: 0.2727 - val_loss: 1.7492
# Epoch 318/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 0.4723 - loss: 1.3723 - val_acc: 0.3030 - val_loss: 1.7246
# Epoch 319/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.3971 - loss: 1.4026 - val_acc: 0.2727 - val_loss: 1.7326
# Epoch 320/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4645 - loss: 1.3294 - val_acc: 0.2121 - val_loss: 1.6729
# Epoch 321/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.4697 - loss: 1.3171 - val_acc: 0.3030 - val_loss: 1.7031
# Epoch 322/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4407 - loss: 1.3747 - val_acc: 0.3333 - val_loss: 1.7242
# Epoch 323/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.4769 - loss: 1.3867 - val_acc: 0.4242 - val_loss: 1.7065
# Epoch 324/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4381 - loss: 1.4424 - val_acc: 0.3939 - val_loss: 1.6234
# Epoch 325/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4583 - loss: 1.3817 - val_acc: 0.4242 - val_loss: 1.5615
# Epoch 326/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4176 - loss: 1.4054 - val_acc: 0.3939 - val_loss: 1.5205
# Epoch 327/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.5134 - loss: 1.2396 - val_acc: 0.4242 - val_loss: 1.5006
# Epoch 328/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.4449 - loss: 1.3621 - val_acc: 0.3939 - val_loss: 1.5225
# Epoch 329/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - acc: 0.4094 - loss: 1.4126 - val_acc: 0.4545 - val_loss: 1.5708
# Epoch 330/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.5192 - loss: 1.3061 - val_acc: 0.3939 - val_loss: 1.6045
# Epoch 331/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4228 - loss: 1.3704 - val_acc: 0.4545 - val_loss: 1.6335
# Epoch 332/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.4788 - loss: 1.3098 - val_acc: 0.3939 - val_loss: 1.6378
# Epoch 333/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.5202 - loss: 1.3570 - val_acc: 0.4242 - val_loss: 1.6236
# Epoch 334/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 0.5254 - loss: 1.3036 - val_acc: 0.4242 - val_loss: 1.6178
# Epoch 335/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4661 - loss: 1.3378 - val_acc: 0.4545 - val_loss: 1.6359
# Epoch 336/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.5329 - loss: 1.2973 - val_acc: 0.4545 - val_loss: 1.7000
# Epoch 337/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.4466 - loss: 1.3844 - val_acc: 0.4545 - val_loss: 1.7421
# Epoch 338/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - acc: 0.4831 - loss: 1.3633 - val_acc: 0.3636 - val_loss: 1.7241
# Epoch 339/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4638 - loss: 1.3339 - val_acc: 0.3333 - val_loss: 1.6930
# Epoch 340/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.5104 - loss: 1.2530 - val_acc: 0.3939 - val_loss: 1.7006
# Epoch 341/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - acc: 0.5117 - loss: 1.3441 - val_acc: 0.3939 - val_loss: 1.7117
# Epoch 342/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4619 - loss: 1.4322 - val_acc: 0.3636 - val_loss: 1.7467
# Epoch 343/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.4293 - loss: 1.4410 - val_acc: 0.3030 - val_loss: 1.7919
# Epoch 344/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4805 - loss: 1.3686 - val_acc: 0.2727 - val_loss: 1.7570
# Epoch 345/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4655 - loss: 1.3273 - val_acc: 0.3333 - val_loss: 1.7092
# Epoch 346/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - acc: 0.4909 - loss: 1.3823 - val_acc: 0.3939 - val_loss: 1.6949
# Epoch 347/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.4958 - loss: 1.2578 - val_acc: 0.3939 - val_loss: 1.6956
# Epoch 348/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4186 - loss: 1.3757 - val_acc: 0.3636 - val_loss: 1.6853
# Epoch 349/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - acc: 0.4980 - loss: 1.2629 - val_acc: 0.3939 - val_loss: 1.6692
# Epoch 350/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.4805 - loss: 1.3530 - val_acc: 0.4545 - val_loss: 1.6109
# Epoch 351/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.4912 - loss: 1.3687 - val_acc: 0.4545 - val_loss: 1.6074
# Epoch 352/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.4811 - loss: 1.3740 - val_acc: 0.3939 - val_loss: 1.6957
# Epoch 353/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4919 - loss: 1.3292 - val_acc: 0.3939 - val_loss: 1.6910
# Epoch 354/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.5166 - loss: 1.3558 - val_acc: 0.3939 - val_loss: 1.6829
# Epoch 355/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4857 - loss: 1.2976 - val_acc: 0.3636 - val_loss: 1.7054
# Epoch 356/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - acc: 0.5306 - loss: 1.3306 - val_acc: 0.3939 - val_loss: 1.7304
# Epoch 357/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 0.5120 - loss: 1.2694 - val_acc: 0.3939 - val_loss: 1.7148
# Epoch 358/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - acc: 0.4449 - loss: 1.3488 - val_acc: 0.3939 - val_loss: 1.7260
# Epoch 359/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - acc: 0.5143 - loss: 1.3366 - val_acc: 0.3939 - val_loss: 1.7439
# Epoch 360/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - acc: 0.5134 - loss: 1.3270 - val_acc: 0.3333 - val_loss: 1.7357
# Epoch 361/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - acc: 0.4928 - loss: 1.3455 - val_acc: 0.3636 - val_loss: 1.7446
# Epoch 362/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - acc: 0.5433 - loss: 1.2796 - val_acc: 0.3939 - val_loss: 1.7835
# Epoch 363/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - acc: 0.4495 - loss: 1.3689 - val_acc: 0.4242 - val_loss: 1.7893
# Epoch 364/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - acc: 0.4629 - loss: 1.2942 - val_acc: 0.3939 - val_loss: 1.7125
# Epoch 365/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - acc: 0.4381 - loss: 1.3590 - val_acc: 0.3636 - val_loss: 1.6850
# Epoch 366/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - acc: 0.4645 - loss: 1.3833 - val_acc: 0.3636 - val_loss: 1.6355
# Epoch 367/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - acc: 0.4752 - loss: 1.3360 - val_acc: 0.3636 - val_loss: 1.5985
# Epoch 368/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 0.4928 - loss: 1.3157 - val_acc: 0.4545 - val_loss: 1.6058
# Epoch 369/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - acc: 0.4785 - loss: 1.3332 - val_acc: 0.4848 - val_loss: 1.6399
# Epoch 370/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - acc: 0.4785 - loss: 1.3159 - val_acc: 0.4545 - val_loss: 1.6528
# Epoch 371/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - acc: 0.4557 - loss: 1.4167 - val_acc: 0.3636 - val_loss: 1.6486
# Epoch 372/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - acc: 0.5078 - loss: 1.2346 - val_acc: 0.3939 - val_loss: 1.6661
# Epoch 373/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - acc: 0.4847 - loss: 1.2888 - val_acc: 0.3939 - val_loss: 1.6681
# Epoch 374/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - acc: 0.4739 - loss: 1.3897 - val_acc: 0.3333 - val_loss: 1.6576
# Epoch 375/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.4583 - loss: 1.3928 - val_acc: 0.3939 - val_loss: 1.6638
# Epoch 376/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4023 - loss: 1.4645 - val_acc: 0.3939 - val_loss: 1.6613
# Epoch 377/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.5046 - loss: 1.3110 - val_acc: 0.3333 - val_loss: 1.6774
# Epoch 378/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4140 - loss: 1.4322 - val_acc: 0.3636 - val_loss: 1.7250
# Epoch 379/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - acc: 0.4912 - loss: 1.3831 - val_acc: 0.3636 - val_loss: 1.7094
# Epoch 380/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 0.3909 - loss: 1.3182 - val_acc: 0.3939 - val_loss: 1.6892
# Epoch 381/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.4469 - loss: 1.3702 - val_acc: 0.4848 - val_loss: 1.7166
# Epoch 382/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - acc: 0.4958 - loss: 1.3102 - val_acc: 0.4545 - val_loss: 1.7045
# Epoch 383/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.4440 - loss: 1.4134 - val_acc: 0.4848 - val_loss: 1.6742
# Epoch 384/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4912 - loss: 1.3759 - val_acc: 0.4242 - val_loss: 1.7075
# Epoch 385/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4772 - loss: 1.2988 - val_acc: 0.3636 - val_loss: 1.7421
# Epoch 386/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.4785 - loss: 1.4237 - val_acc: 0.3030 - val_loss: 1.7638
# Epoch 387/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4726 - loss: 1.2990 - val_acc: 0.3636 - val_loss: 1.7114
# Epoch 388/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.4964 - loss: 1.3125 - val_acc: 0.3939 - val_loss: 1.7287
# Epoch 389/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - acc: 0.5117 - loss: 1.2748 - val_acc: 0.4242 - val_loss: 1.6995
# Epoch 390/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.5515 - loss: 1.2164 - val_acc: 0.3939 - val_loss: 1.6950
# Epoch 391/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.4840 - loss: 1.2917 - val_acc: 0.3939 - val_loss: 1.7171
# Epoch 392/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - acc: 0.4593 - loss: 1.3278 - val_acc: 0.3030 - val_loss: 1.7909
# Epoch 393/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.4661 - loss: 1.3028 - val_acc: 0.3333 - val_loss: 1.8570
# Epoch 394/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.4945 - loss: 1.3695 - val_acc: 0.3636 - val_loss: 1.7708
# Epoch 395/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.4192 - loss: 1.3377 - val_acc: 0.4242 - val_loss: 1.7612
# Epoch 396/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.5016 - loss: 1.2975 - val_acc: 0.5455 - val_loss: 1.7317
# Epoch 397/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - acc: 0.4088 - loss: 1.3364 - val_acc: 0.4848 - val_loss: 1.6829
# Epoch 398/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - acc: 0.4876 - loss: 1.3454 - val_acc: 0.5152 - val_loss: 1.6646
# Epoch 399/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 0.5463 - loss: 1.2531 - val_acc: 0.4848 - val_loss: 1.6077
# Epoch 400/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.4866 - loss: 1.3388 - val_acc: 0.5152 - val_loss: 1.5524

# %%
display_learning_curves(history)

# %%
# Evaluate the baseline_model on the test instances of the node feature dataset and retrieve the test accuracy.
_, test_accuracy = baseline_model.evaluate(x=x_test, y=y_test, verbose=0)
# Print the test accuracy rounded to two decimal places.
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# Test accuracy: 57.93%

# %%
def generate_random_instances(num_instances):
    # Calculate the probability of each token appearing in the training data
    token_probability = x_train.mean(axis=0)

    # Generate random instances based on token probabilities
    instances = []
    for _ in range(num_instances):
        # Generate random probabilities for each token
        probabilities = np.random.uniform(size=len(token_probability))
        # Create an instance where tokens are set based on their probabilities
        instance = (probabilities <= token_probability).astype(int)
        instances.append(instance)

    return np.array(instances)


def display_class_probabilities(probabilities):
    # Display probabilities for each instance and class
    for instance_idx, probs in enumerate(probabilities):
        print(f"Instance {instance_idx + 1}:")
        # Display probabilities for each class
        for class_idx, prob in enumerate(probs):
            print(f"- {class_values[class_idx]}: {round(prob * 100, 2)}%")

# %%
new_instances = generate_random_instances(num_classes)
logits = baseline_model.predict(new_instances)
probabilities = keras.activations.softmax(tf.convert_to_tensor(logits)).numpy()
display_class_probabilities(probabilities)
# Out:
# 1/1 [==============================] - 0s 448ms/step
# Instance 1:
# - 1: 48.57%
# - 2: 8.74%
# - 3: 5.29%
# - 4: 1.7%
# - 5: 2.08%
# - 6: 29.45%
# - 7: 1.3%
# - 8: 2.87%
# Instance 2:
# - 1: 48.57%
# - 2: 8.74%
# - 3: 5.29%
# - 4: 1.7%
# - 5: 2.08%
# - 6: 29.45%
# - 7: 1.3%
# - 8: 2.87%
# Instance 3:
# - 1: 48.57%
# - 2: 8.74%
# - 3: 5.29%
# - 4: 1.7%
# - 5: 2.08%
# - 6: 29.45%
# - 7: 1.3%
# - 8: 2.87%
# Instance 4:
# - 1: 48.57%
# - 2: 8.74%
# - 3: 5.29%
# - 4: 1.7%
# - 5: 2.08%
# - 6: 29.45%
# - 7: 1.3%
# - 8: 2.87%
# Instance 5:
# - 1: 4.39%
# - 2: 0.13%
# - 3: 0.76%
# - 4: 21.66%
# - 5: 0.01%
# - 6: 11.09%
# - 7: 59.02%
# - 8: 2.92%
# Instance 6:
# - 1: 48.57%
# - 2: 8.74%
# - 3: 5.29%
# - 4: 1.7%
# - 5: 2.08%
# - 6: 29.45%
# - 7: 1.3%
# - 8: 2.87%
# Instance 7:
# - 1: 48.57%
# - 2: 8.74%
# - 3: 5.29%
# - 4: 1.7%
# - 5: 2.08%
# - 6: 29.45%
# - 7: 1.3%
# - 8: 2.87%
# Instance 8:
# - 1: 48.57%
# - 2: 8.74%
# - 3: 5.29%
# - 4: 1.7%
# - 5: 2.08%
# - 6: 29.45%
# - 7: 1.3%
# - 8: 2.87%

# %% [markdown]
# #Graph Data Classification with the GNN Model

# %%
# Create an edges array (sparse adjacency matrix) of shape [2, num_edges].
edges = Graph_data[["source", "target"]].to_numpy().T

# Create an edge weights array of ones.
edge_weights = tf.ones(shape=edges.shape[1])

# Create a node features array of shape [num_nodes, num_features].
node_features = tf.cast(
    Node_Feature.sort_values("US_ID")[feature_names].to_numpy(),
    dtype=tf.dtypes.float32
)

# Create graph info tuple with node_features, edges, and edge_weights.
graph_info = (node_features, edges, edge_weights)

# Print shapes for verification.
print("Edges shape:", edges.shape)
print("Nodes shape:", node_features.shape)
# Out:
# Edges shape: (2, 714610)
# Nodes shape: (1196, 6)

# %%
class GraphConvLayer(layers.Layer):
    def __init__(
        self,
        hidden_units,
        dropout_rate=0.3,
        aggregation_type="mean",
        combination_type="ConvLSTM1D",
        normalize=False,
        *args,
        **kwargs,
    ):
        super().__init__(*args, **kwargs)

        # Initialize layer parameters
        self.aggregation_type = aggregation_type  # Type of aggregation (sum, mean, max)
        self.combination_type = combination_type  # Type of combination (gated, ConvLSTM1D, concat, add)
        self.normalize = normalize  # Whether to normalize node embeddings

        # Create feedforward network for message preparation
        self.ffn_prepare = create_ffn(hidden_units, dropout_rate)

        # Define update function based on combination type
        if self.combination_type == "gated":
            # GRU for gated combination
            self.update_fn = layers.GRU(
                units=hidden_units,
                activation="relu",
                recurrent_activation="elu",
                dropout=dropout_rate,
                return_state=True,
                recurrent_dropout=dropout_rate,
            )
        else:
            # Feedforward network for other combination types
            self.update_fn = create_ffn(hidden_units, dropout_rate)

    def prepare(self, node_repesentations, weights=None):
        # Prepare messages from node representations
        messages = self.ffn_prepare(node_repesentations)
        if weights is not None:
            # Apply weights if provided
            messages = messages * tf.expand_dims(weights, -1)
        return messages

    def aggregate(self, node_indices, neighbour_messages, node_repesentations):
        # Aggregate neighbour messages based on aggregation type
        num_nodes = node_repesentations.shape[0]
        if self.aggregation_type == "sum":
            # Sum neighbour messages per node
            aggregated_message = tf.math.unsorted_segment_sum(
                neighbour_messages, node_indices, num_segments=num_nodes
            )
        elif self.aggregation_type == "mean":
            # Average neighbour messages per node
            aggregated_message = tf.math.unsorted_segment_mean(
                neighbour_messages, node_indices, num_segments=num_nodes
            )
        elif self.aggregation_type == "max":
            # Maximum neighbour messages per node
            aggregated_message = tf.math.unsorted_segment_max(
                neighbour_messages, node_indices, num_segments=num_nodes
            )
        else:
            # Handle invalid aggregation type
            raise ValueError(f"Invalid aggregation type: {self.aggregation_type}.")

        return aggregated_message

    def update(self, node_repesentations, aggregated_messages):
        # Update node representations based on combination type
        if self.combination_type == "ConvLSTM1D":
            # Stack node and aggregated messages for ConvLSTM1D
            h = tf.stack([node_repesentations, aggregated_messages], axis=1)
        elif self.combination_type == "concat":
            # Concatenate node and aggregated messages
            h = tf.concat([node_repesentations, aggregated_messages], axis=1)
        elif self.combination_type == "add":
            # Add node and aggregated messages
            h = node_repesentations + aggregated_messages
        else:
            # Handle invalid combination type
            raise ValueError(f"Invalid combination type: {self.combination_type}.")

        # Apply update function (GRU or feedforward network)
        node_embeddings = self.update_fn(h)

        # For ConvLSTM1D, extract final output
        if self.combination_type == "ConvLSTM1D":
            node_embeddings = tf.unstack(node_embeddings, axis=1)[-1]

        # Normalize node embeddings
        if self.normalize:
            node_embeddings = tf.nn.l2_normalize(node_embeddings, axis=-1)
        return node_embeddings

    def call(self, inputs):
        """Process inputs to produce node embeddings."""
        node_repesentations, edges, edge_weights = inputs

        # Get source (node_indices) and target (neighbour_indices) from edges
        node_indices, neighbour_indices = edges[0], edges[1]

        # Gather neighbour representations
        neighbour_repesentations = tf.gather(node_repesentations, neighbour_indices)

        # Prepare neighbour messages
        neighbour_messages = self.prepare(neighbour_repesentations, edge_weights)

        # Aggregate neighbour messages
        aggregated_messages = self.aggregate(
            node_indices, neighbour_messages, node_repesentations
        )

        # Update node representations with aggregated messages
        return self.update(node_repesentations, aggregated_messages)

# %%
class GNNNodeClassifier(tf.keras.Model):
    def __init__(
        self,
        graph_info,
        num_classes,
        hidden_units,
        aggregation_type="sum",
        combination_type="concat",
        dropout_rate=0.3,
        normalize=True,
        *args,
        **kwargs,
    ):
        super().__init__(*args, **kwargs)

        # Unpack graph_info into node_features, edges, and edge_weights.
        node_features, edges, edge_weights = graph_info
        self.node_features = node_features  # Node features of the graph
        self.edges = edges  # Edges connecting nodes
        self.edge_weights = edge_weights  # Weights associated with each edge

        # Set edge_weights to 1.0 if not provided.
        if self.edge_weights is None:
            self.edge_weights = tf.ones(shape=edges.shape[1])
        # Scale edge_weights to sum to 1.
        self.edge_weights = self.edge_weights / tf.math.reduce_sum(self.edge_weights)

        # Create a preprocessing layer.
        self.preprocess = create_ffn(hidden_units, dropout_rate, name="preprocess")

        # Create the first GraphConv layer.
        self.conv1 = GraphConvLayer(
            hidden_units,
            dropout_rate,
            aggregation_type,
            combination_type,
            normalize,
            name="graph_conv1",
        )

        # Create the second GraphConv layer.
        self.conv2 = GraphConvLayer(
            hidden_units,
            dropout_rate,
            aggregation_type,
            combination_type,
            normalize,
            name="graph_conv2",
        )

        # Create a postprocessing layer.
        self.postprocess = create_ffn(hidden_units, dropout_rate, name="postprocess")

        # Create a layer to compute logits for classification.
        self.compute_logits = layers.Dense(units=num_classes, name="logits")

    def call(self, input_node_indices):
        # Preprocess node_features to produce initial node representations.
        x = self.preprocess(self.node_features)

        # Apply the first graph convolutional layer.
        x1 = self.conv1((x, self.edges, self.edge_weights))

        # Skip connection: add the output of the first layer to the input features.
        x = x1 + x

        # Apply the second graph convolutional layer.
        x2 = self.conv2((x, self.edges, self.edge_weights))

        # Skip connection: add the output of the second layer to the previous output.
        x = x2 + x

        # Postprocess node embeddings.
        x = self.postprocess(x)

        # Fetch node embeddings for the specified input node indices.
        node_embeddings = tf.gather(x, input_node_indices)

        # Compute logits for classification.
        return self.compute_logits(node_embeddings)

# %% [markdown]
# This code snippet defines a Graph Neural Network (GNN) model for node classification. It initializes the model with parameters such as graph information (graph_info), number of output classes (num_classes), hidden layer units (hidden_units), dropout rate (dropout_rate), and assigns a name to the model ("gnn_model").

# %%
gnn_model = GNNNodeClassifier(
    graph_info=graph_info,
    num_classes=num_classes,
    hidden_units=hidden_units,
    dropout_rate=dropout_rate,
    name="gnn_model",
)

print("GNN output shape:", gnn_model([1, 10, 100])) #prints the output shape of the GNN model when given input data of sizes [1, 10, 100]. This shows how the model processes input data and produces an output shape.

gnn_model.summary() #This line prints a summary of the GNN model, showing its architecture including the types and shapes of its layers, the number of parameters, and how the data flows through the model.
# Out:
# GNN output shape: tf.Tensor(
# [[ 0.02234409  0.32525     0.13556682 -0.16205709 -0.38821936  0.0970222
#   -0.2296652   0.14256671]
#  [-0.0264589   0.24492991  0.1652877   0.3520807  -0.22509778  0.39926982
#    0.25216022 -0.0231567 ]
#  [-0.1455959  -0.1896675   0.02418885  0.1576142   0.1945878  -0.06087385
#    0.34520555 -0.21532759]], shape=(3, 8), dtype=float32)
# Model: "gnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  preprocess (Sequential)     (1196, 64)                4888
#
#  graph_conv1 (GraphConvLaye  multiple                  22016
#  r)
#
#  graph_conv2 (GraphConvLaye  multiple                  22016
#  r)
#
#  postprocess (Sequential)    (1196, 64)                8832
#
#  logits (Dense)              multiple                  520
#
# =================================================================
# Total params: 58272 (227.62 KB)
# Trainable params: 56596 (221.08 KB)
# Non-trainable params: 1676 (6.55 KB)
# _________________________________________________________________

# %%
x_train = train_data.US_ID.to_numpy()  # Extracting the 'US_ID' column from 'train_data' and converting it to a NumPy array.

history = run_experiment(gnn_model, x_train, y_train)  # Running an experiment using 'gnn_model', 'x_train', and 'y_train', storing results in 'history'.
# Out:
# Epoch 1/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 15s 4s/step - acc: 0.1310 - loss: 2.0166 - val_acc: 0.2727 - val_loss: 2.3417
# Epoch 2/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.3218 - loss: 2.0677 - val_acc: 0.4242 - val_loss: 1.8120
# Epoch 3/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 0.3508 - loss: 1.6953 - val_acc: 0.3030 - val_loss: 1.8144
# Epoch 4/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 0.3114 - loss: 1.7296 - val_acc: 0.4545 - val_loss: 1.7265
# Epoch 5/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.3511 - loss: 1.6268 - val_acc: 0.3333 - val_loss: 1.7122
# Epoch 6/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 0.3691 - loss: 1.5943 - val_acc: 0.4242 - val_loss: 1.6006
# Epoch 7/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - acc: 0.4319 - loss: 1.4841 - val_acc: 0.5152 - val_loss: 1.4409
# Epoch 8/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 0.4909 - loss: 1.4236 - val_acc: 0.4242 - val_loss: 1.5758
# Epoch 9/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 0.4082 - loss: 1.4998 - val_acc: 0.3636 - val_loss: 1.6209
# Epoch 10/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.4762 - loss: 1.3535 - val_acc: 0.5455 - val_loss: 1.5106
# Epoch 11/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 0.4948 - loss: 1.3243 - val_acc: 0.4242 - val_loss: 1.6279
# Epoch 12/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 0.5752 - loss: 1.2430 - val_acc: 0.5758 - val_loss: 1.3535
# Epoch 13/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - acc: 0.6134 - loss: 1.0311 - val_acc: 0.4848 - val_loss: 1.4651
# Epoch 14/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 0.5752 - loss: 1.1150 - val_acc: 0.4545 - val_loss: 1.7766
# Epoch 15/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - acc: 0.5267 - loss: 1.2929 - val_acc: 0.5758 - val_loss: 1.3466
# Epoch 16/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 0.6332 - loss: 0.9333 - val_acc: 0.4848 - val_loss: 1.4454
# Epoch 17/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 0.6746 - loss: 0.8944 - val_acc: 0.5455 - val_loss: 1.3307
# Epoch 18/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.7029 - loss: 0.7680 - val_acc: 0.5455 - val_loss: 1.2696
# Epoch 19/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 0.7013 - loss: 0.7237 - val_acc: 0.6364 - val_loss: 1.2619
# Epoch 20/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - acc: 0.7459 - loss: 0.6602 - val_acc: 0.6364 - val_loss: 1.2502
# Epoch 21/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 0.7065 - loss: 0.7357 - val_acc: 0.4848 - val_loss: 1.3413
# Epoch 22/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.7251 - loss: 0.6774 - val_acc: 0.5455 - val_loss: 1.3902
# Epoch 23/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.7684 - loss: 0.5516 - val_acc: 0.5455 - val_loss: 1.4716
# Epoch 24/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.7209 - loss: 0.6604 - val_acc: 0.6061 - val_loss: 1.2919
# Epoch 25/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - acc: 0.8234 - loss: 0.4921 - val_acc: 0.5455 - val_loss: 1.4053
# Epoch 26/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - acc: 0.7987 - loss: 0.5186 - val_acc: 0.6061 - val_loss: 1.4466
# Epoch 27/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.8270 - loss: 0.4360 - val_acc: 0.6061 - val_loss: 1.2880
# Epoch 28/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 0.8661 - loss: 0.4000 - val_acc: 0.6061 - val_loss: 1.4409
# Epoch 29/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 0.8238 - loss: 0.4883 - val_acc: 0.6364 - val_loss: 1.4482
# Epoch 30/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 0.8352 - loss: 0.3667 - val_acc: 0.6364 - val_loss: 1.4906
# Epoch 31/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.8023 - loss: 0.4910 - val_acc: 0.6364 - val_loss: 1.7482
# Epoch 32/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.8635 - loss: 0.3785 - val_acc: 0.5758 - val_loss: 1.6547
# Epoch 33/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.8909 - loss: 0.2916 - val_acc: 0.5758 - val_loss: 1.6731
# Epoch 34/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.9140 - loss: 0.2596 - val_acc: 0.6667 - val_loss: 1.7132
# Epoch 35/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.8564 - loss: 0.3037 - val_acc: 0.5455 - val_loss: 1.6071
# Epoch 36/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - acc: 0.8902 - loss: 0.2780 - val_acc: 0.6061 - val_loss: 1.5442
# Epoch 37/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 0.9120 - loss: 0.2661 - val_acc: 0.5152 - val_loss: 1.9115
# Epoch 38/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - acc: 0.9254 - loss: 0.2347 - val_acc: 0.6061 - val_loss: 1.6875
# Epoch 39/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 0.9016 - loss: 0.2624 - val_acc: 0.6061 - val_loss: 1.7745
# Epoch 40/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 0.9352 - loss: 0.1886 - val_acc: 0.6061 - val_loss: 1.6924
# Epoch 41/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 0.9485 - loss: 0.1760 - val_acc: 0.6364 - val_loss: 1.5831
# Epoch 42/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.9397 - loss: 0.1670 - val_acc: 0.6061 - val_loss: 1.7694
# Epoch 43/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 0.9521 - loss: 0.1313 - val_acc: 0.6061 - val_loss: 1.8593
# Epoch 44/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.9671 - loss: 0.1153 - val_acc: 0.5758 - val_loss: 1.7993
# Epoch 45/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - acc: 0.9717 - loss: 0.0997 - val_acc: 0.6061 - val_loss: 1.9004
# Epoch 46/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 0.0790 - val_acc: 0.5758 - val_loss: 2.0875
# Epoch 47/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 0.9752 - loss: 0.0843 - val_acc: 0.5455 - val_loss: 2.1954
# Epoch 48/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 0.9938 - loss: 0.0584 - val_acc: 0.6061 - val_loss: 2.2422
# Epoch 49/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 0.9938 - loss: 0.0491 - val_acc: 0.5455 - val_loss: 2.2551
# Epoch 50/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 0.9964 - loss: 0.0368 - val_acc: 0.6061 - val_loss: 2.3359
# Epoch 51/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 1.0000 - loss: 0.0402 - val_acc: 0.6061 - val_loss: 2.4292
# Epoch 52/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 1.0000 - loss: 0.0288 - val_acc: 0.6061 - val_loss: 2.5323
# Epoch 53/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 1.0000 - loss: 0.0239 - val_acc: 0.6364 - val_loss: 2.6535
# Epoch 54/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - acc: 1.0000 - loss: 0.0217 - val_acc: 0.5758 - val_loss: 2.7674
# Epoch 55/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - acc: 1.0000 - loss: 0.0173 - val_acc: 0.5758 - val_loss: 2.8246
# Epoch 56/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - acc: 1.0000 - loss: 0.0153 - val_acc: 0.6061 - val_loss: 2.9540
# Epoch 57/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - acc: 1.0000 - loss: 0.0147 - val_acc: 0.6061 - val_loss: 2.9990
# Epoch 58/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - acc: 1.0000 - loss: 0.0115 - val_acc: 0.6061 - val_loss: 3.0272
# Epoch 59/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - acc: 1.0000 - loss: 0.0099 - val_acc: 0.6061 - val_loss: 3.1010
# Epoch 60/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - acc: 1.0000 - loss: 0.0087 - val_acc: 0.6061 - val_loss: 3.1117
# Epoch 61/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - acc: 1.0000 - loss: 0.0090 - val_acc: 0.5758 - val_loss: 3.1911
# Epoch 62/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - acc: 1.0000 - loss: 0.0070 - val_acc: 0.5758 - val_loss: 3.2624
# Epoch 63/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - acc: 1.0000 - loss: 0.0062 - val_acc: 0.5758 - val_loss: 3.3235
# Epoch 64/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - acc: 1.0000 - loss: 0.0055 - val_acc: 0.5758 - val_loss: 3.3757
# Epoch 65/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - acc: 1.0000 - loss: 0.0050 - val_acc: 0.5758 - val_loss: 3.4092
# Epoch 66/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - acc: 1.0000 - loss: 0.0046 - val_acc: 0.5758 - val_loss: 3.4592
# Epoch 67/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - acc: 1.0000 - loss: 0.0043 - val_acc: 0.5758 - val_loss: 3.4735
# Epoch 68/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - acc: 1.0000 - loss: 0.0041 - val_acc: 0.5758 - val_loss: 3.4943
# Epoch 69/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - acc: 1.0000 - loss: 0.0039 - val_acc: 0.5758 - val_loss: 3.5242
# Epoch 70/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - acc: 1.0000 - loss: 0.0036 - val_acc: 0.5758 - val_loss: 3.5797
# Epoch 71/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 0.0034 - val_acc: 0.5758 - val_loss: 3.6154
# Epoch 72/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 0.0032 - val_acc: 0.5758 - val_loss: 3.6445
# Epoch 73/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 1.0000 - loss: 0.0030 - val_acc: 0.5758 - val_loss: 3.6621
# Epoch 74/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 0.0027 - val_acc: 0.5758 - val_loss: 3.6830
# Epoch 75/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 0.0026 - val_acc: 0.5758 - val_loss: 3.7157
# Epoch 76/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 0.0026 - val_acc: 0.5758 - val_loss: 3.7524
# Epoch 77/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 1.0000 - loss: 0.0023 - val_acc: 0.5758 - val_loss: 3.7871
# Epoch 78/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 1.0000 - loss: 0.0023 - val_acc: 0.5758 - val_loss: 3.8094
# Epoch 79/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 0.0022 - val_acc: 0.5758 - val_loss: 3.8237
# Epoch 80/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - acc: 1.0000 - loss: 0.0021 - val_acc: 0.5758 - val_loss: 3.8366
# Epoch 81/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - acc: 1.0000 - loss: 0.0020 - val_acc: 0.5758 - val_loss: 3.8555
# Epoch 82/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - acc: 1.0000 - loss: 0.0020 - val_acc: 0.5758 - val_loss: 3.8743
# Epoch 83/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 0.0019 - val_acc: 0.5758 - val_loss: 3.8919
# Epoch 84/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 0.0019 - val_acc: 0.5758 - val_loss: 3.9109
# Epoch 85/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 0.0017 - val_acc: 0.5758 - val_loss: 3.9216
# Epoch 86/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 0.0017 - val_acc: 0.5758 - val_loss: 3.9369
# Epoch 87/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 1.0000 - loss: 0.0016 - val_acc: 0.5758 - val_loss: 3.9590
# Epoch 88/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 0.0016 - val_acc: 0.5758 - val_loss: 3.9840
# Epoch 89/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 0.0015 - val_acc: 0.5758 - val_loss: 4.0037
# Epoch 90/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - acc: 1.0000 - loss: 0.0015 - val_acc: 0.5758 - val_loss: 4.0187
# Epoch 91/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - acc: 1.0000 - loss: 0.0014 - val_acc: 0.5758 - val_loss: 4.0367
# Epoch 92/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 0.0013 - val_acc: 0.5758 - val_loss: 4.0605
# Epoch 93/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 0.0014 - val_acc: 0.5758 - val_loss: 4.0835
# Epoch 94/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 1.0000 - loss: 0.0013 - val_acc: 0.5758 - val_loss: 4.1007
# Epoch 95/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 0.0013 - val_acc: 0.5758 - val_loss: 4.1125
# Epoch 96/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 0.0012 - val_acc: 0.5758 - val_loss: 4.1223
# Epoch 97/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 0.0012 - val_acc: 0.5758 - val_loss: 4.1372
# Epoch 98/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 0.0012 - val_acc: 0.5758 - val_loss: 4.1574
# Epoch 99/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 1.0000 - loss: 0.0011 - val_acc: 0.5758 - val_loss: 4.1754
# Epoch 100/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 1.0000 - loss: 0.0011 - val_acc: 0.5758 - val_loss: 4.1864
# Epoch 101/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - acc: 1.0000 - loss: 0.0011 - val_acc: 0.5758 - val_loss: 4.1951
# Epoch 102/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - acc: 1.0000 - loss: 0.0011 - val_acc: 0.5758 - val_loss: 4.2041
# Epoch 103/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 1.0000 - loss: 0.0010 - val_acc: 0.5758 - val_loss: 4.2134
# Epoch 104/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 1.0000 - loss: 9.9951e-04 - val_acc: 0.5758 - val_loss: 4.2245
# Epoch 105/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 9.9324e-04 - val_acc: 0.5758 - val_loss: 4.2392
# Epoch 106/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - acc: 1.0000 - loss: 9.5028e-04 - val_acc: 0.5758 - val_loss: 4.2538
# Epoch 107/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - acc: 1.0000 - loss: 9.2209e-04 - val_acc: 0.5758 - val_loss: 4.2676
# Epoch 108/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 9.2236e-04 - val_acc: 0.5758 - val_loss: 4.2774
# Epoch 109/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 1.0000 - loss: 8.7449e-04 - val_acc: 0.5758 - val_loss: 4.2845
# Epoch 110/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - acc: 1.0000 - loss: 8.6656e-04 - val_acc: 0.5758 - val_loss: 4.2933
# Epoch 111/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - acc: 1.0000 - loss: 8.2101e-04 - val_acc: 0.5758 - val_loss: 4.3051
# Epoch 112/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 8.6942e-04 - val_acc: 0.5758 - val_loss: 4.3173
# Epoch 113/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - acc: 1.0000 - loss: 8.2691e-04 - val_acc: 0.5758 - val_loss: 4.3309
# Epoch 114/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 7.8778e-04 - val_acc: 0.5758 - val_loss: 4.3441
# Epoch 115/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 7.9868e-04 - val_acc: 0.5758 - val_loss: 4.3549
# Epoch 116/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 1.0000 - loss: 7.8720e-04 - val_acc: 0.5758 - val_loss: 4.3694
# Epoch 117/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 7.5614e-04 - val_acc: 0.5758 - val_loss: 4.3833
# Epoch 118/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - acc: 1.0000 - loss: 7.6817e-04 - val_acc: 0.5758 - val_loss: 4.3941
# Epoch 119/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - acc: 1.0000 - loss: 7.6229e-04 - val_acc: 0.5758 - val_loss: 4.4001
# Epoch 120/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 7.1017e-04 - val_acc: 0.5758 - val_loss: 4.4044
# Epoch 121/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 1.0000 - loss: 6.8245e-04 - val_acc: 0.5758 - val_loss: 4.4084
# Epoch 122/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 1.0000 - loss: 6.6450e-04 - val_acc: 0.5758 - val_loss: 4.4111
# Epoch 123/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 1.0000 - loss: 6.8438e-04 - val_acc: 0.5758 - val_loss: 4.4134
# Epoch 124/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 6.6963e-04 - val_acc: 0.5758 - val_loss: 4.4142
# Epoch 125/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 6.5249e-04 - val_acc: 0.5758 - val_loss: 4.4169
# Epoch 126/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 1.0000 - loss: 6.5660e-04 - val_acc: 0.5758 - val_loss: 4.4256
# Epoch 127/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 1.0000 - loss: 6.3546e-04 - val_acc: 0.5758 - val_loss: 4.4391
# Epoch 128/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 6.1134e-04 - val_acc: 0.5758 - val_loss: 4.4546
# Epoch 129/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - acc: 1.0000 - loss: 5.8673e-04 - val_acc: 0.5758 - val_loss: 4.4703
# Epoch 130/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 1.0000 - loss: 5.8790e-04 - val_acc: 0.5758 - val_loss: 4.4827
# Epoch 131/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 5.9074e-04 - val_acc: 0.5758 - val_loss: 4.4926
# Epoch 132/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 5.7003e-04 - val_acc: 0.5758 - val_loss: 4.5016
# Epoch 133/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 5.8217e-04 - val_acc: 0.5758 - val_loss: 4.5085
# Epoch 134/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 5.5658e-04 - val_acc: 0.5758 - val_loss: 4.5159
# Epoch 135/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 5.4530e-04 - val_acc: 0.5758 - val_loss: 4.5230
# Epoch 136/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 5.4880e-04 - val_acc: 0.5758 - val_loss: 4.5314
# Epoch 137/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 1.0000 - loss: 5.1609e-04 - val_acc: 0.5758 - val_loss: 4.5422
# Epoch 138/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 1.0000 - loss: 5.2939e-04 - val_acc: 0.5758 - val_loss: 4.5530
# Epoch 139/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - acc: 1.0000 - loss: 5.0792e-04 - val_acc: 0.5758 - val_loss: 4.5606
# Epoch 140/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - acc: 1.0000 - loss: 4.9449e-04 - val_acc: 0.5758 - val_loss: 4.5664
# Epoch 141/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - acc: 1.0000 - loss: 4.8800e-04 - val_acc: 0.5758 - val_loss: 4.5716
# Epoch 142/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 4.9743e-04 - val_acc: 0.5758 - val_loss: 4.5788
# Epoch 143/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - acc: 1.0000 - loss: 4.9374e-04 - val_acc: 0.5758 - val_loss: 4.5842
# Epoch 144/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 1.0000 - loss: 4.8587e-04 - val_acc: 0.5758 - val_loss: 4.5911
# Epoch 145/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 4.7046e-04 - val_acc: 0.5758 - val_loss: 4.5960
# Epoch 146/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 4.6358e-04 - val_acc: 0.5758 - val_loss: 4.5996
# Epoch 147/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 4.5839e-04 - val_acc: 0.5758 - val_loss: 4.6062
# Epoch 148/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 1.0000 - loss: 4.4053e-04 - val_acc: 0.5758 - val_loss: 4.6145
# Epoch 149/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 4.2811e-04 - val_acc: 0.5758 - val_loss: 4.6195
# Epoch 150/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - acc: 1.0000 - loss: 4.1586e-04 - val_acc: 0.5758 - val_loss: 4.6247
# Epoch 151/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - acc: 1.0000 - loss: 4.5865e-04 - val_acc: 0.5758 - val_loss: 4.6311
# Epoch 152/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 4.2135e-04 - val_acc: 0.5758 - val_loss: 4.6383
# Epoch 153/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 1.0000 - loss: 4.0538e-04 - val_acc: 0.5758 - val_loss: 4.6474
# Epoch 154/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 4.1399e-04 - val_acc: 0.5758 - val_loss: 4.6596
# Epoch 155/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 3.9618e-04 - val_acc: 0.5758 - val_loss: 4.6713
# Epoch 156/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 3.9162e-04 - val_acc: 0.5758 - val_loss: 4.6822
# Epoch 157/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 4.0355e-04 - val_acc: 0.5758 - val_loss: 4.6898
# Epoch 158/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - acc: 1.0000 - loss: 3.8937e-04 - val_acc: 0.5758 - val_loss: 4.6939
# Epoch 159/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 3.7794e-04 - val_acc: 0.5758 - val_loss: 4.6994
# Epoch 160/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 1.0000 - loss: 3.8003e-04 - val_acc: 0.5758 - val_loss: 4.7038
# Epoch 161/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - acc: 1.0000 - loss: 3.8294e-04 - val_acc: 0.5758 - val_loss: 4.7103
# Epoch 162/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - acc: 1.0000 - loss: 3.7108e-04 - val_acc: 0.5758 - val_loss: 4.7181
# Epoch 163/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 3.8433e-04 - val_acc: 0.5758 - val_loss: 4.7274
# Epoch 164/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 1.0000 - loss: 3.5319e-04 - val_acc: 0.5758 - val_loss: 4.7371
# Epoch 165/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 3.5374e-04 - val_acc: 0.5758 - val_loss: 4.7456
# Epoch 166/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 3.4687e-04 - val_acc: 0.5758 - val_loss: 4.7531
# Epoch 167/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 3.5518e-04 - val_acc: 0.5758 - val_loss: 4.7599
# Epoch 168/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 1.0000 - loss: 3.4369e-04 - val_acc: 0.5758 - val_loss: 4.7655
# Epoch 169/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 1.0000 - loss: 3.3275e-04 - val_acc: 0.5758 - val_loss: 4.7690
# Epoch 170/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - acc: 1.0000 - loss: 3.3379e-04 - val_acc: 0.5758 - val_loss: 4.7717
# Epoch 171/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - acc: 1.0000 - loss: 3.2855e-04 - val_acc: 0.5758 - val_loss: 4.7756
# Epoch 172/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - acc: 1.0000 - loss: 3.1868e-04 - val_acc: 0.5758 - val_loss: 4.7799
# Epoch 173/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - acc: 1.0000 - loss: 3.1942e-04 - val_acc: 0.5758 - val_loss: 4.7841
# Epoch 174/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - acc: 1.0000 - loss: 3.1350e-04 - val_acc: 0.5758 - val_loss: 4.7872
# Epoch 175/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - acc: 1.0000 - loss: 3.0797e-04 - val_acc: 0.5758 - val_loss: 4.7894
# Epoch 176/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - acc: 1.0000 - loss: 3.1459e-04 - val_acc: 0.5758 - val_loss: 4.7911
# Epoch 177/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - acc: 1.0000 - loss: 3.0448e-04 - val_acc: 0.5758 - val_loss: 4.7936
# Epoch 178/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - acc: 1.0000 - loss: 3.1465e-04 - val_acc: 0.5758 - val_loss: 4.7970
# Epoch 179/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - acc: 1.0000 - loss: 2.9766e-04 - val_acc: 0.5758 - val_loss: 4.8027
# Epoch 180/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - acc: 1.0000 - loss: 2.9874e-04 - val_acc: 0.5758 - val_loss: 4.8090
# Epoch 181/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 1.0000 - loss: 2.8424e-04 - val_acc: 0.5758 - val_loss: 4.8182
# Epoch 182/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - acc: 1.0000 - loss: 3.0264e-04 - val_acc: 0.5758 - val_loss: 4.8285
# Epoch 183/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 1.0000 - loss: 2.6896e-04 - val_acc: 0.5758 - val_loss: 4.8392
# Epoch 184/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - acc: 1.0000 - loss: 2.8575e-04 - val_acc: 0.5758 - val_loss: 4.8491
# Epoch 185/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - acc: 1.0000 - loss: 2.8229e-04 - val_acc: 0.5758 - val_loss: 4.8566
# Epoch 186/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - acc: 1.0000 - loss: 2.8274e-04 - val_acc: 0.5758 - val_loss: 4.8623
# Epoch 187/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - acc: 1.0000 - loss: 2.6704e-04 - val_acc: 0.5758 - val_loss: 4.8685
# Epoch 188/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 2.6801e-04 - val_acc: 0.5758 - val_loss: 4.8754
# Epoch 189/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - acc: 1.0000 - loss: 2.7087e-04 - val_acc: 0.5758 - val_loss: 4.8823
# Epoch 190/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - acc: 1.0000 - loss: 2.6228e-04 - val_acc: 0.5758 - val_loss: 4.8885
# Epoch 191/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 2.5881e-04 - val_acc: 0.5758 - val_loss: 4.8943
# Epoch 192/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 2.6266e-04 - val_acc: 0.5758 - val_loss: 4.9000
# Epoch 193/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 1.0000 - loss: 2.5973e-04 - val_acc: 0.5758 - val_loss: 4.9049
# Epoch 194/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 2.5637e-04 - val_acc: 0.5758 - val_loss: 4.9080
# Epoch 195/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 2.4691e-04 - val_acc: 0.5758 - val_loss: 4.9146
# Epoch 196/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 1.0000 - loss: 2.4170e-04 - val_acc: 0.5758 - val_loss: 4.9220
# Epoch 197/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - acc: 1.0000 - loss: 2.4575e-04 - val_acc: 0.6061 - val_loss: 4.9279
# Epoch 198/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 2.3322e-04 - val_acc: 0.5758 - val_loss: 4.9327
# Epoch 199/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 2.4288e-04 - val_acc: 0.5758 - val_loss: 4.9348
# Epoch 200/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 2.4662e-04 - val_acc: 0.5455 - val_loss: 4.9364
# Epoch 201/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 2.3134e-04 - val_acc: 0.5455 - val_loss: 4.9387
# Epoch 202/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 1.0000 - loss: 2.2338e-04 - val_acc: 0.5455 - val_loss: 4.9418
# Epoch 203/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 1.0000 - loss: 2.2477e-04 - val_acc: 0.5455 - val_loss: 4.9458
# Epoch 204/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 2.2637e-04 - val_acc: 0.5455 - val_loss: 4.9505
# Epoch 205/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 2.2570e-04 - val_acc: 0.5455 - val_loss: 4.9561
# Epoch 206/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 2.2957e-04 - val_acc: 0.5455 - val_loss: 4.9621
# Epoch 207/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - acc: 1.0000 - loss: 2.2193e-04 - val_acc: 0.5455 - val_loss: 4.9683
# Epoch 208/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - acc: 1.0000 - loss: 2.1477e-04 - val_acc: 0.5455 - val_loss: 4.9743
# Epoch 209/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 2.1565e-04 - val_acc: 0.5455 - val_loss: 4.9789
# Epoch 210/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 1.0000 - loss: 2.0439e-04 - val_acc: 0.5758 - val_loss: 4.9840
# Epoch 211/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 1.0000 - loss: 2.1143e-04 - val_acc: 0.6061 - val_loss: 4.9900
# Epoch 212/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - acc: 1.0000 - loss: 2.0609e-04 - val_acc: 0.6061 - val_loss: 4.9956
# Epoch 213/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 2.0944e-04 - val_acc: 0.5758 - val_loss: 4.9995
# Epoch 214/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 2.0200e-04 - val_acc: 0.5758 - val_loss: 5.0023
# Epoch 215/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 2.0231e-04 - val_acc: 0.5758 - val_loss: 5.0043
# Epoch 216/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 1.9718e-04 - val_acc: 0.5758 - val_loss: 5.0080
# Epoch 217/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - acc: 1.0000 - loss: 1.9492e-04 - val_acc: 0.5758 - val_loss: 5.0143
# Epoch 218/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - acc: 1.0000 - loss: 1.9711e-04 - val_acc: 0.5455 - val_loss: 5.0204
# Epoch 219/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 1.0000 - loss: 1.8700e-04 - val_acc: 0.5455 - val_loss: 5.0261
# Epoch 220/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - acc: 1.0000 - loss: 2.0029e-04 - val_acc: 0.5455 - val_loss: 5.0311
# Epoch 221/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 1.9249e-04 - val_acc: 0.5455 - val_loss: 5.0348
# Epoch 222/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - acc: 1.0000 - loss: 1.9359e-04 - val_acc: 0.5455 - val_loss: 5.0380
# Epoch 223/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 1.8653e-04 - val_acc: 0.5455 - val_loss: 5.0407
# Epoch 224/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 1.7336e-04 - val_acc: 0.5455 - val_loss: 5.0437
# Epoch 225/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 1.0000 - loss: 1.8470e-04 - val_acc: 0.5455 - val_loss: 5.0481
# Epoch 226/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 1.0000 - loss: 1.7857e-04 - val_acc: 0.5455 - val_loss: 5.0536
# Epoch 227/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 1.0000 - loss: 1.8582e-04 - val_acc: 0.5455 - val_loss: 5.0605
# Epoch 228/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 1.7623e-04 - val_acc: 0.5455 - val_loss: 5.0672
# Epoch 229/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 1.0000 - loss: 1.8192e-04 - val_acc: 0.5455 - val_loss: 5.0738
# Epoch 230/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 1.7908e-04 - val_acc: 0.5455 - val_loss: 5.0808
# Epoch 231/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 1.7676e-04 - val_acc: 0.5455 - val_loss: 5.0876
# Epoch 232/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - acc: 1.0000 - loss: 1.7653e-04 - val_acc: 0.5455 - val_loss: 5.0944
# Epoch 233/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 1.7250e-04 - val_acc: 0.5455 - val_loss: 5.1017
# Epoch 234/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 1.6715e-04 - val_acc: 0.5758 - val_loss: 5.1083
# Epoch 235/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - acc: 1.0000 - loss: 1.7075e-04 - val_acc: 0.5758 - val_loss: 5.1143
# Epoch 236/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 1.0000 - loss: 1.7059e-04 - val_acc: 0.6061 - val_loss: 5.1198
# Epoch 237/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 1.0000 - loss: 1.5911e-04 - val_acc: 0.6061 - val_loss: 5.1227
# Epoch 238/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - acc: 1.0000 - loss: 1.6450e-04 - val_acc: 0.6061 - val_loss: 5.1244
# Epoch 239/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - acc: 1.0000 - loss: 1.6413e-04 - val_acc: 0.6061 - val_loss: 5.1269
# Epoch 240/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 1.0000 - loss: 1.5771e-04 - val_acc: 0.6061 - val_loss: 5.1293
# Epoch 241/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - acc: 1.0000 - loss: 1.5793e-04 - val_acc: 0.6061 - val_loss: 5.1310
# Epoch 242/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - acc: 1.0000 - loss: 1.6252e-04 - val_acc: 0.6061 - val_loss: 5.1322
# Epoch 243/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 1.0000 - loss: 1.5854e-04 - val_acc: 0.5455 - val_loss: 5.1344
# Epoch 244/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 1.5851e-04 - val_acc: 0.5455 - val_loss: 5.1372
# Epoch 245/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 1.0000 - loss: 1.5565e-04 - val_acc: 0.5455 - val_loss: 5.1413
# Epoch 246/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 1.5252e-04 - val_acc: 0.5455 - val_loss: 5.1460
# Epoch 247/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - acc: 1.0000 - loss: 1.4871e-04 - val_acc: 0.5455 - val_loss: 5.1526
# Epoch 248/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - acc: 1.0000 - loss: 1.5201e-04 - val_acc: 0.5455 - val_loss: 5.1597
# Epoch 249/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - acc: 1.0000 - loss: 1.4862e-04 - val_acc: 0.5455 - val_loss: 5.1671
# Epoch 250/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - acc: 1.0000 - loss: 1.4488e-04 - val_acc: 0.5455 - val_loss: 5.1749
# Epoch 251/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 1.4039e-04 - val_acc: 0.5455 - val_loss: 5.1825
# Epoch 252/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 1.0000 - loss: 1.4727e-04 - val_acc: 0.5758 - val_loss: 5.1897
# Epoch 253/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 1.4644e-04 - val_acc: 0.5758 - val_loss: 5.1951
# Epoch 254/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 1.0000 - loss: 1.4469e-04 - val_acc: 0.5455 - val_loss: 5.1989
# Epoch 255/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - acc: 1.0000 - loss: 1.4935e-04 - val_acc: 0.5455 - val_loss: 5.2022
# Epoch 256/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 1.0000 - loss: 1.3933e-04 - val_acc: 0.5455 - val_loss: 5.2047
# Epoch 257/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 1.4132e-04 - val_acc: 0.5455 - val_loss: 5.2083
# Epoch 258/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - acc: 1.0000 - loss: 1.4025e-04 - val_acc: 0.5455 - val_loss: 5.2127
# Epoch 259/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 1.3168e-04 - val_acc: 0.5455 - val_loss: 5.2164
# Epoch 260/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - acc: 1.0000 - loss: 1.3392e-04 - val_acc: 0.5455 - val_loss: 5.2195
# Epoch 261/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 1.3704e-04 - val_acc: 0.5455 - val_loss: 5.2216
# Epoch 262/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - acc: 1.0000 - loss: 1.3920e-04 - val_acc: 0.5455 - val_loss: 5.2239
# Epoch 263/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - acc: 1.0000 - loss: 1.3675e-04 - val_acc: 0.5455 - val_loss: 5.2263
# Epoch 264/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 1.3074e-04 - val_acc: 0.5455 - val_loss: 5.2289
# Epoch 265/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - acc: 1.0000 - loss: 1.3708e-04 - val_acc: 0.5455 - val_loss: 5.2315
# Epoch 266/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 1.2657e-04 - val_acc: 0.5455 - val_loss: 5.2338
# Epoch 267/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - acc: 1.0000 - loss: 1.3064e-04 - val_acc: 0.5455 - val_loss: 5.2360
# Epoch 268/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - acc: 1.0000 - loss: 1.2906e-04 - val_acc: 0.5455 - val_loss: 5.2385
# Epoch 269/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 1.2537e-04 - val_acc: 0.5455 - val_loss: 5.2404
# Epoch 270/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 1.3080e-04 - val_acc: 0.5455 - val_loss: 5.2435
# Epoch 271/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - acc: 1.0000 - loss: 1.2525e-04 - val_acc: 0.5455 - val_loss: 5.2481
# Epoch 272/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - acc: 1.0000 - loss: 1.2589e-04 - val_acc: 0.5455 - val_loss: 5.2527
# Epoch 273/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - acc: 1.0000 - loss: 1.2411e-04 - val_acc: 0.5455 - val_loss: 5.2566
# Epoch 274/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - acc: 1.0000 - loss: 1.2638e-04 - val_acc: 0.5455 - val_loss: 5.2612
# Epoch 275/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - acc: 1.0000 - loss: 1.2273e-04 - val_acc: 0.5455 - val_loss: 5.2660
# Epoch 276/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - acc: 1.0000 - loss: 1.1995e-04 - val_acc: 0.5455 - val_loss: 5.2692
# Epoch 277/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - acc: 1.0000 - loss: 1.2196e-04 - val_acc: 0.5455 - val_loss: 5.2712
# Epoch 278/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - acc: 1.0000 - loss: 1.1775e-04 - val_acc: 0.5455 - val_loss: 5.2727
# Epoch 279/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - acc: 1.0000 - loss: 1.2097e-04 - val_acc: 0.5455 - val_loss: 5.2748
# Epoch 280/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - acc: 1.0000 - loss: 1.2247e-04 - val_acc: 0.5455 - val_loss: 5.2758
# Epoch 281/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - acc: 1.0000 - loss: 1.1485e-04 - val_acc: 0.5455 - val_loss: 5.2771
# Epoch 282/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - acc: 1.0000 - loss: 1.1535e-04 - val_acc: 0.5455 - val_loss: 5.2803
# Epoch 283/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - acc: 1.0000 - loss: 1.1159e-04 - val_acc: 0.5758 - val_loss: 5.2832
# Epoch 284/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - acc: 1.0000 - loss: 1.2009e-04 - val_acc: 0.5758 - val_loss: 5.2860
# Epoch 285/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - acc: 1.0000 - loss: 1.1339e-04 - val_acc: 0.5758 - val_loss: 5.2894
# Epoch 286/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - acc: 1.0000 - loss: 1.1452e-04 - val_acc: 0.5758 - val_loss: 5.2935
# Epoch 287/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - acc: 1.0000 - loss: 1.0439e-04 - val_acc: 0.5758 - val_loss: 5.2982
# Epoch 288/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - acc: 1.0000 - loss: 1.1011e-04 - val_acc: 0.5758 - val_loss: 5.3010
# Epoch 289/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 1.0000 - loss: 1.0707e-04 - val_acc: 0.5758 - val_loss: 5.3026
# Epoch 290/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - acc: 1.0000 - loss: 1.0515e-04 - val_acc: 0.5758 - val_loss: 5.3055
# Epoch 291/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - acc: 1.0000 - loss: 1.0905e-04 - val_acc: 0.5758 - val_loss: 5.3093
# Epoch 292/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 1.0000 - loss: 1.0586e-04 - val_acc: 0.5758 - val_loss: 5.3133
# Epoch 293/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - acc: 1.0000 - loss: 1.0696e-04 - val_acc: 0.5758 - val_loss: 5.3174
# Epoch 294/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 1.0916e-04 - val_acc: 0.5455 - val_loss: 5.3211
# Epoch 295/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - acc: 1.0000 - loss: 1.0711e-04 - val_acc: 0.5455 - val_loss: 5.3240
# Epoch 296/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 1.0542e-04 - val_acc: 0.5455 - val_loss: 5.3266
# Epoch 297/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 1.0387e-04 - val_acc: 0.5455 - val_loss: 5.3296
# Epoch 298/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 1.0000 - loss: 1.0467e-04 - val_acc: 0.5455 - val_loss: 5.3329
# Epoch 299/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - acc: 1.0000 - loss: 1.0409e-04 - val_acc: 0.5455 - val_loss: 5.3371
# Epoch 300/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 1.0000 - loss: 9.9705e-05 - val_acc: 0.5455 - val_loss: 5.3428
# Epoch 301/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 1.0550e-04 - val_acc: 0.5455 - val_loss: 5.3484
# Epoch 302/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 1.0000 - loss: 1.0070e-04 - val_acc: 0.5455 - val_loss: 5.3537
# Epoch 303/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 1.0130e-04 - val_acc: 0.5758 - val_loss: 5.3592
# Epoch 304/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 1.0318e-04 - val_acc: 0.5758 - val_loss: 5.3638
# Epoch 305/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 9.9939e-05 - val_acc: 0.5758 - val_loss: 5.3675
# Epoch 306/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 1.0000 - loss: 9.4043e-05 - val_acc: 0.5758 - val_loss: 5.3705
# Epoch 307/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - acc: 1.0000 - loss: 9.8835e-05 - val_acc: 0.5758 - val_loss: 5.3718
# Epoch 308/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - acc: 1.0000 - loss: 9.4784e-05 - val_acc: 0.5758 - val_loss: 5.3732
# Epoch 309/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - acc: 1.0000 - loss: 9.5495e-05 - val_acc: 0.5758 - val_loss: 5.3745
# Epoch 310/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 1.0000 - loss: 9.2926e-05 - val_acc: 0.5758 - val_loss: 5.3751
# Epoch 311/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 9.3387e-05 - val_acc: 0.5758 - val_loss: 5.3751
# Epoch 312/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 9.3172e-05 - val_acc: 0.5758 - val_loss: 5.3768
# Epoch 313/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 9.1686e-05 - val_acc: 0.5758 - val_loss: 5.3807
# Epoch 314/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 1.0000 - loss: 9.2977e-05 - val_acc: 0.5758 - val_loss: 5.3860
# Epoch 315/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 9.5562e-05 - val_acc: 0.5758 - val_loss: 5.3907
# Epoch 316/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 9.0405e-05 - val_acc: 0.5758 - val_loss: 5.3943
# Epoch 317/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - acc: 1.0000 - loss: 9.3110e-05 - val_acc: 0.5758 - val_loss: 5.3982
# Epoch 318/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 1.0000 - loss: 9.2517e-05 - val_acc: 0.5758 - val_loss: 5.4028
# Epoch 319/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - acc: 1.0000 - loss: 8.7729e-05 - val_acc: 0.5758 - val_loss: 5.4069
# Epoch 320/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 9.1225e-05 - val_acc: 0.5758 - val_loss: 5.4109
# Epoch 321/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 1.0000 - loss: 9.0122e-05 - val_acc: 0.5758 - val_loss: 5.4148
# Epoch 322/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 1.0000 - loss: 8.6251e-05 - val_acc: 0.5758 - val_loss: 5.4178
# Epoch 323/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 1.0000 - loss: 8.7067e-05 - val_acc: 0.5758 - val_loss: 5.4205
# Epoch 324/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - acc: 1.0000 - loss: 9.1486e-05 - val_acc: 0.5758 - val_loss: 5.4241
# Epoch 325/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 8.5579e-05 - val_acc: 0.5758 - val_loss: 5.4276
# Epoch 326/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - acc: 1.0000 - loss: 8.7317e-05 - val_acc: 0.5758 - val_loss: 5.4306
# Epoch 327/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 8.3581e-05 - val_acc: 0.5758 - val_loss: 5.4334
# Epoch 328/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 8.4743e-05 - val_acc: 0.5758 - val_loss: 5.4362
# Epoch 329/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - acc: 1.0000 - loss: 8.8915e-05 - val_acc: 0.5758 - val_loss: 5.4392
# Epoch 330/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - acc: 1.0000 - loss: 8.6476e-05 - val_acc: 0.5758 - val_loss: 5.4420
# Epoch 331/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - acc: 1.0000 - loss: 8.0728e-05 - val_acc: 0.5758 - val_loss: 5.4448
# Epoch 332/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 8.4417e-05 - val_acc: 0.5758 - val_loss: 5.4474
# Epoch 333/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - acc: 1.0000 - loss: 8.2757e-05 - val_acc: 0.5758 - val_loss: 5.4511
# Epoch 334/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - acc: 1.0000 - loss: 8.0686e-05 - val_acc: 0.5758 - val_loss: 5.4550
# Epoch 335/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 1.0000 - loss: 8.4607e-05 - val_acc: 0.5758 - val_loss: 5.4588
# Epoch 336/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 8.2426e-05 - val_acc: 0.5758 - val_loss: 5.4633
# Epoch 337/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 1.0000 - loss: 8.4173e-05 - val_acc: 0.5758 - val_loss: 5.4675
# Epoch 338/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 8.1456e-05 - val_acc: 0.5758 - val_loss: 5.4707
# Epoch 339/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 8.0554e-05 - val_acc: 0.5758 - val_loss: 5.4733
# Epoch 340/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 1.0000 - loss: 7.9211e-05 - val_acc: 0.5758 - val_loss: 5.4749
# Epoch 341/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 7.7231e-05 - val_acc: 0.5758 - val_loss: 5.4761
# Epoch 342/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 7.8564e-05 - val_acc: 0.5758 - val_loss: 5.4767
# Epoch 343/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - acc: 1.0000 - loss: 7.5699e-05 - val_acc: 0.5758 - val_loss: 5.4779
# Epoch 344/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - acc: 1.0000 - loss: 7.7349e-05 - val_acc: 0.5758 - val_loss: 5.4804
# Epoch 345/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 1.0000 - loss: 7.7425e-05 - val_acc: 0.5758 - val_loss: 5.4843
# Epoch 346/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 7.4714e-05 - val_acc: 0.5758 - val_loss: 5.4890
# Epoch 347/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 1.0000 - loss: 7.5992e-05 - val_acc: 0.5758 - val_loss: 5.4941
# Epoch 348/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 1.0000 - loss: 7.7858e-05 - val_acc: 0.5758 - val_loss: 5.4997
# Epoch 349/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 7.5428e-05 - val_acc: 0.5758 - val_loss: 5.5037
# Epoch 350/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 7.2996e-05 - val_acc: 0.5758 - val_loss: 5.5061
# Epoch 351/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 7.5748e-05 - val_acc: 0.5758 - val_loss: 5.5075
# Epoch 352/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 1.0000 - loss: 7.6970e-05 - val_acc: 0.5758 - val_loss: 5.5086
# Epoch 353/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - acc: 1.0000 - loss: 7.3671e-05 - val_acc: 0.5758 - val_loss: 5.5100
# Epoch 354/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 7.0460e-05 - val_acc: 0.5758 - val_loss: 5.5118
# Epoch 355/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 1.0000 - loss: 7.3769e-05 - val_acc: 0.5758 - val_loss: 5.5146
# Epoch 356/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 7.3812e-05 - val_acc: 0.5758 - val_loss: 5.5177
# Epoch 357/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 7.4197e-05 - val_acc: 0.5758 - val_loss: 5.5211
# Epoch 358/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - acc: 1.0000 - loss: 6.9954e-05 - val_acc: 0.5758 - val_loss: 5.5250
# Epoch 359/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - acc: 1.0000 - loss: 6.7123e-05 - val_acc: 0.5758 - val_loss: 5.5278
# Epoch 360/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - acc: 1.0000 - loss: 6.9323e-05 - val_acc: 0.5758 - val_loss: 5.5303
# Epoch 361/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - acc: 1.0000 - loss: 6.9069e-05 - val_acc: 0.5758 - val_loss: 5.5335
# Epoch 362/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - acc: 1.0000 - loss: 7.2526e-05 - val_acc: 0.5758 - val_loss: 5.5369
# Epoch 363/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 6.7328e-05 - val_acc: 0.5758 - val_loss: 5.5406
# Epoch 364/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - acc: 1.0000 - loss: 6.8855e-05 - val_acc: 0.5758 - val_loss: 5.5429
# Epoch 365/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 6.9878e-05 - val_acc: 0.5758 - val_loss: 5.5437
# Epoch 366/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 6.7335e-05 - val_acc: 0.5758 - val_loss: 5.5445
# Epoch 367/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 6.8375e-05 - val_acc: 0.5758 - val_loss: 5.5459
# Epoch 368/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - acc: 1.0000 - loss: 6.6964e-05 - val_acc: 0.5758 - val_loss: 5.5475
# Epoch 369/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 1.0000 - loss: 6.6792e-05 - val_acc: 0.5758 - val_loss: 5.5498
# Epoch 370/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - acc: 1.0000 - loss: 6.5914e-05 - val_acc: 0.5758 - val_loss: 5.5522
# Epoch 371/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - acc: 1.0000 - loss: 6.5862e-05 - val_acc: 0.5758 - val_loss: 5.5544
# Epoch 372/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - acc: 1.0000 - loss: 6.4371e-05 - val_acc: 0.5758 - val_loss: 5.5569
# Epoch 373/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - acc: 1.0000 - loss: 6.5942e-05 - val_acc: 0.5758 - val_loss: 5.5601
# Epoch 374/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - acc: 1.0000 - loss: 6.7082e-05 - val_acc: 0.5758 - val_loss: 5.5638
# Epoch 375/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - acc: 1.0000 - loss: 6.4882e-05 - val_acc: 0.5758 - val_loss: 5.5667
# Epoch 376/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - acc: 1.0000 - loss: 6.5339e-05 - val_acc: 0.5758 - val_loss: 5.5693
# Epoch 377/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - acc: 1.0000 - loss: 6.6667e-05 - val_acc: 0.5758 - val_loss: 5.5728
# Epoch 378/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - acc: 1.0000 - loss: 6.4377e-05 - val_acc: 0.5758 - val_loss: 5.5763
# Epoch 379/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - acc: 1.0000 - loss: 6.1732e-05 - val_acc: 0.5758 - val_loss: 5.5793
# Epoch 380/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - acc: 1.0000 - loss: 6.4044e-05 - val_acc: 0.5758 - val_loss: 5.5819
# Epoch 381/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - acc: 1.0000 - loss: 6.2918e-05 - val_acc: 0.5758 - val_loss: 5.5838
# Epoch 382/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - acc: 1.0000 - loss: 6.2031e-05 - val_acc: 0.5758 - val_loss: 5.5848
# Epoch 383/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - acc: 1.0000 - loss: 6.2189e-05 - val_acc: 0.5758 - val_loss: 5.5862
# Epoch 384/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - acc: 1.0000 - loss: 6.3317e-05 - val_acc: 0.5758 - val_loss: 5.5882
# Epoch 385/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - acc: 1.0000 - loss: 6.1384e-05 - val_acc: 0.5758 - val_loss: 5.5901
# Epoch 386/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - acc: 1.0000 - loss: 6.0158e-05 - val_acc: 0.5758 - val_loss: 5.5915
# Epoch 387/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - acc: 1.0000 - loss: 5.8796e-05 - val_acc: 0.5758 - val_loss: 5.5933
# Epoch 388/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - acc: 1.0000 - loss: 6.0292e-05 - val_acc: 0.5758 - val_loss: 5.5957
# Epoch 389/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - acc: 1.0000 - loss: 6.0769e-05 - val_acc: 0.5758 - val_loss: 5.5989
# Epoch 390/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - acc: 1.0000 - loss: 5.8205e-05 - val_acc: 0.5758 - val_loss: 5.6025
# Epoch 391/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - acc: 1.0000 - loss: 6.0055e-05 - val_acc: 0.5758 - val_loss: 5.6062
# Epoch 392/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - acc: 1.0000 - loss: 5.6039e-05 - val_acc: 0.5758 - val_loss: 5.6089
# Epoch 393/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - acc: 1.0000 - loss: 5.8896e-05 - val_acc: 0.5758 - val_loss: 5.6119
# Epoch 394/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - acc: 1.0000 - loss: 6.0184e-05 - val_acc: 0.5758 - val_loss: 5.6144
# Epoch 395/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - acc: 1.0000 - loss: 5.9323e-05 - val_acc: 0.5758 - val_loss: 5.6165
# Epoch 396/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 5.9373e-05 - val_acc: 0.5758 - val_loss: 5.6181
# Epoch 397/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - acc: 1.0000 - loss: 5.8455e-05 - val_acc: 0.5758 - val_loss: 5.6198
# Epoch 398/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - acc: 1.0000 - loss: 5.7330e-05 - val_acc: 0.5758 - val_loss: 5.6222
# Epoch 399/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - acc: 1.0000 - loss: 5.7930e-05 - val_acc: 0.5758 - val_loss: 5.6244
# Epoch 400/400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - acc: 1.0000 - loss: 5.4179e-05 - val_acc: 0.5758 - val_loss: 5.6270

# %%
display_learning_curves(history)

# %%
# Extracting the unique node IDs from the test_data and converting them to a NumPy array.
x_test = test_data.US_ID.to_numpy()

# Evaluating the trained GNN model on the test dataset,
# calculating the accuracy without verbosity (verbose=0).
_, test_accuracy = gnn_model.evaluate(x=x_test, y=y_test, verbose=0)

# Printing the test accuracy as a percentage rounded to two decimal places.
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# Test accuracy: 92.8%

# %%
import numpy as np

# Using the trained GNN model (gnn_model) to predict probabilities for each class
# on the test input data (x_test).
y_pred_prob = gnn_model.predict(x_test)

# Extracting the predicted class labels by choosing the highest probability index
# along axis 1 (columns) from the predicted probabilities.
y_pred = np.argmax(y_pred_prob, axis=1)
# Out:
# 11/11 [==============================] - 1s 50ms/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Calculating the confusion matrix using true labels (y_true) and predicted labels (y_pred).
cm = confusion_matrix(y_test, y_pred)

# Creating a heatmap of the confusion matrix using seaborn, with annotations and a blue color map.
plt.figure(figsize=(10, 7))  # Optional: Set the figure size
sns.heatmap(cm, annot=True, cmap="Blues", fmt="d")

# Labeling the x-axis and y-axis of the heatmap.
plt.xlabel("Predicted labels")
plt.ylabel("True labels")

# Saving the figure with a specified filename and DPI before displaying it.
plt.savefig("confusion_matrix.png", dpi=600)

# Displaying the heatmap.
plt.show()
